# %% [markdown]
# # Cell 1: Download models if needed

# %%
import stanza

# Only download if not already present (silently)
for (lang, package) in [('en', None), ('en', 'bc5cdr')]:
    try:
        stanza.Pipeline(lang=lang, processors='tokenize,ner', package=package or 'default', verbose=False)
    except Exception:
        stanza.download(lang, package=package)

# %% [markdown]
# # Cell 2: Load the sample text

# %%
# Sample dialogue (as a string)
text = """
Patient: "Hi Dr. Carter. My name is Sarah, I’m here because I’ve been struggling with anxiety and depression since starting at Newton University in September."

Therapist: "Nice to meet you, Sarah. I’m Dr. Carter, a psychiatrist at the Boston Mind Health Center. Can you tell me more about your symptoms?"

Patient: "Mostly I feel constant fatigue, and I’ve had headaches every morning since the Halloween event on campus. My mom, Robyn, is worried because she thinks I might need Zoloft or Lexapro, but I haven’t tried either."

Therapist: "It’s understandable to feel overwhelmed, especially with your course load and the transition to university life. Are you currently taking any medication or supplements?"

Patient: "I tried Tylenol and Advil for the headaches, but they don’t help. I also bought a new sleep tracker and some noise-cancelling headphones, but nothing seems to make a difference."

Therapist: "Have you considered attending the wellness group for freshmen? Sometimes talking to peers with similar experiences can be helpful, especially for students from different backgrounds."

Patient: "I heard about that group during orientation, but I haven’t joined. I worry my schedule won’t allow it, and honestly, I’m not sure if talking will help."

Therapist: "Have you spoken with your primary care doctor at Newton General Hospital about these symptoms? Also, are there any other medical conditions in your family history?"

Patient: "My mom’s side has a history of migraine and insomnia, but I don’t think anyone’s had anxiety like this. Robyn suggested I journal my symptoms and use the meditation app she downloaded on my phone."

Therapist: "Let’s try some practical steps: keep a daily log of your headaches and sleep patterns, consider meeting with the freshman group, and follow up with me in two weeks. If symptoms worsen, we can discuss medication options like Zoloft or Lexapro at your next appointment."
"""

# %% [markdown]
# # Cell 3: Run Stanza pipelines & display NER, dependency, constituency

# %%
# Load Stanza pipelines (once)
nlp_en = stanza.Pipeline(
    lang='en',
    processors='tokenize,pos,lemma,ner,depparse,constituency',
    use_gpu=False,
    verbose=False
)
nlp_bc5cdr = stanza.Pipeline(
    lang='en',
    processors='tokenize,ner',
    package={'ner': 'bc5cdr', 'tokenize': 'default'},
    use_gpu=False,
    verbose=False
)

# Run on the full text (as a big chunk)
doc_en = nlp_en(text)
doc_bc5cdr = nlp_bc5cdr(text)

# Print NER (English)
print("="*30, "\nGENERAL ENGLISH (default)\n", "="*30)
print("-- Named Entities --")
for ent in doc_en.ents:
    print(f"  {ent.text:30}  ({ent.type})")

print("\n-- Dependency Parse (token/parent/rel) --")
for sent in doc_en.sentences:
    for word in sent.words:
        head = sent.words[word.head-1].text if word.head > 0 else 'ROOT'
        print(f"  {word.text:15} ← {head:15}  ({word.deprel})")

print("\n-- Constituency Parse --")
for sent in doc_en.sentences:
    print(sent.constituency)

print("\n" + "="*30, "\nBIOMEDICAL NER (BC5CDR)\n", "="*30)
print("-- Named Entities --")
for ent in doc_bc5cdr.ents:
    print(f"  {ent.text:30}  ({ent.type})")
# Out:
# ==============================
# GENERAL ENGLISH (default)
#  ==============================
# -- Named Entities --
#   Carter                          (PERSON)
#   Sarah                           (PERSON)
#   Newton University               (ORG)
#   September                       (DATE)
#   Sarah                           (PERSON)
#   Carter                          (PERSON)
#   the Boston Mind Health Center   (ORG)
#   Halloween                       (DATE)
#   Robyn                           (PERSON)
#   Lexapro                         (PRODUCT)
#   Newton General Hospital         (FAC)
#   Robyn                           (PERSON)
#   two weeks                       (DATE)
#   Zoloft                          (PRODUCT)
#   Lexapro                         (PRODUCT)
#
# -- Dependency Parse (token/parent/rel) --
#   Patient         ← ROOT             (root)
#   :               ← Dr.              (punct)
#   "               ← Dr.              (punct)
#   Hi              ← Dr.              (discourse)
#   Dr.             ← Patient          (dep)
#   Carter          ← Dr.              (flat)
#   .               ← Patient          (punct)
#   My              ← name             (nmod:poss)
#   name            ← Sarah            (nsubj)
#   is              ← Sarah            (cop)
#   Sarah           ← ROOT             (root)
#   ,               ← here             (punct)
#   I               ← here             (nsubj)
#   ’m              ← here             (cop)
#   here            ← Sarah            (parataxis)
#   because         ← struggling       (mark)
#   I               ← struggling       (nsubj)
#   ’ve             ← struggling       (aux)
#   been            ← struggling       (aux)
#   struggling      ← here             (advcl)
#   with            ← anxiety          (case)
#   anxiety         ← struggling       (obl)
#   and             ← depression       (cc)
#   depression      ← anxiety          (conj)
#   since           ← starting         (mark)
#   starting        ← struggling       (advcl)
#   at              ← University       (case)
#   Newton          ← University       (compound)
#   University      ← starting         (obl)
#   in              ← September        (case)
#   September       ← starting         (obl)
#   .               ← Sarah            (punct)
#   "               ← Sarah            (punct)
#   Therapist       ← ROOT             (root)
#   :               ← Nice             (punct)
#   "               ← Nice             (punct)
#   Nice            ← Therapist        (appos)
#   to              ← meet             (mark)
#   meet            ← Nice             (csubj)
#   you             ← meet             (obj)
#   ,               ← Sarah            (punct)
#   Sarah           ← meet             (vocative)
#   .               ← Therapist        (punct)
#   I               ← Dr.              (nsubj)
#   ’m              ← Dr.              (cop)
#   Dr.             ← ROOT             (root)
#   Carter          ← Dr.              (flat)
#   ,               ← psychiatrist     (punct)
#   a               ← psychiatrist     (det)
#   psychiatrist    ← Dr.              (appos)
#   at              ← Center           (case)
#   the             ← Center           (det)
#   Boston          ← Center           (compound)
#   Mind            ← Center           (compound)
#   Health          ← Center           (compound)
#   Center          ← psychiatrist     (nmod)
#   .               ← Dr.              (punct)
#   Can             ← tell             (aux)
#   you             ← tell             (nsubj)
#   tell            ← ROOT             (root)
#   me              ← tell             (iobj)
#   more            ← tell             (obj)
#   about           ← symptoms         (case)
#   your            ← symptoms         (nmod:poss)
#   symptoms        ← more             (obl)
#   ?               ← tell             (punct)
#   "               ← tell             (punct)
#   Patient         ← ROOT             (root)
#   :               ← feel             (punct)
#   "               ← feel             (punct)
#   Mostly          ← feel             (advmod)
#   I               ← feel             (nsubj)
#   feel            ← Patient          (appos)
#   constant        ← fatigue          (amod)
#   fatigue         ← feel             (obj)
#   ,               ← had              (punct)
#   and             ← had              (cc)
#   I               ← had              (nsubj)
#   ’ve             ← had              (aux)
#   had             ← feel             (conj)
#   headaches       ← had              (obj)
#   every           ← morning          (det)
#   morning         ← had              (obl:unmarked)
#   since           ← event            (case)
#   the             ← event            (det)
#   Halloween       ← event            (compound)
#   event           ← had              (obl)
#   on              ← campus           (case)
#   campus          ← event            (nmod)
#   .               ← Patient          (punct)
#   My              ← mom              (nmod:poss)
#   mom             ← worried          (nsubj)
#   ,               ← Robyn            (punct)
#   Robyn           ← mom              (appos)
#   ,               ← mom              (punct)
#   is              ← worried          (cop)
#   worried         ← ROOT             (root)
#   because         ← thinks           (mark)
#   she             ← thinks           (nsubj)
#   thinks          ← worried          (advcl)
#   I               ← need             (nsubj)
#   might           ← need             (aux)
#   need            ← thinks           (ccomp)
#   Zoloft          ← need             (obj)
#   or              ← Lexapro          (cc)
#   Lexapro         ← Zoloft           (conj)
#   ,               ← tried            (punct)
#   but             ← tried            (cc)
#   I               ← tried            (nsubj)
#   have            ← tried            (aux)
#   n’t             ← tried            (advmod)
#   tried           ← worried          (conj)
#   either          ← tried            (obj)
#   .               ← worried          (punct)
#   "               ← worried          (punct)
#   Therapist       ← ROOT             (root)
#   :               ← understandable   (punct)
#   "               ← understandable   (punct)
#   It              ← understandable   (expl)
#   ’s              ← understandable   (cop)
#   understandable  ← Therapist        (appos)
#   to              ← feel             (mark)
#   feel            ← understandable   (csubj)
#   overwhelmed     ← feel             (xcomp)
#   ,               ← load             (punct)
#   especially      ← load             (advmod)
#   with            ← load             (case)
#   your            ← load             (nmod:poss)
#   course          ← load             (compound)
#   load            ← overwhelmed      (obl)
#   and             ← transition       (cc)
#   the             ← transition       (det)
#   transition      ← load             (conj)
#   to              ← life             (case)
#   university      ← life             (compound)
#   life            ← transition       (nmod)
#   .               ← Therapist        (punct)
#   Are             ← taking           (aux)
#   you             ← taking           (nsubj)
#   currently       ← taking           (advmod)
#   taking          ← ROOT             (root)
#   any             ← medication       (det)
#   medication      ← taking           (obj)
#   or              ← supplements      (cc)
#   supplements     ← medication       (conj)
#   ?               ← taking           (punct)
#   "               ← taking           (punct)
#   Patient         ← ROOT             (root)
#   :               ← tried            (punct)
#   "               ← tried            (punct)
#   I               ← tried            (nsubj)
#   tried           ← Patient          (appos)
#   Tylenol         ← tried            (obj)
#   and             ← Advil            (cc)
#   Advil           ← Tylenol          (conj)
#   for             ← headaches        (case)
#   the             ← headaches        (det)
#   headaches       ← tried            (obl)
#   ,               ← help             (punct)
#   but             ← help             (cc)
#   they            ← help             (nsubj)
#   do              ← help             (aux)
#   n’t             ← help             (advmod)
#   help            ← tried            (conj)
#   .               ← Patient          (punct)
#   I               ← bought           (nsubj)
#   also            ← bought           (advmod)
#   bought          ← ROOT             (root)
#   a               ← tracker          (det)
#   new             ← tracker          (amod)
#   sleep           ← tracker          (compound)
#   tracker         ← bought           (obj)
#   and             ← headphones       (cc)
#   some            ← headphones       (det)
#   noise           ← cancelling       (compound)
#   -               ← noise            (punct)
#   cancelling      ← headphones       (amod)
#   headphones      ← tracker          (conj)
#   ,               ← seems            (punct)
#   but             ← seems            (cc)
#   nothing         ← seems            (nsubj)
#   seems           ← bought           (conj)
#   to              ← make             (mark)
#   make            ← seems            (xcomp)
#   a               ← difference       (det)
#   difference      ← make             (obj)
#   .               ← bought           (punct)
#   "               ← bought           (punct)
#   Therapist       ← ROOT             (root)
#   :               ← considered       (punct)
#   "               ← considered       (punct)
#   Have            ← considered       (aux)
#   you             ← considered       (nsubj)
#   considered      ← Therapist        (appos)
#   attending       ← considered       (xcomp)
#   the             ← group            (det)
#   wellness        ← group            (amod)
#   group           ← attending        (obj)
#   for             ← freshmen         (case)
#   freshmen        ← attending        (obl)
#   ?               ← Therapist        (punct)
#   Sometimes       ← helpful          (advmod)
#   talking         ← helpful          (csubj)
#   to              ← peers            (case)
#   peers           ← talking          (obl)
#   with            ← experiences      (case)
#   similar         ← experiences      (amod)
#   experiences     ← talking          (obl)
#   can             ← helpful          (aux)
#   be              ← helpful          (cop)
#   helpful         ← ROOT             (root)
#   ,               ← students         (punct)
#   especially      ← students         (advmod)
#   for             ← students         (case)
#   students        ← helpful          (obl)
#   from            ← backgrounds      (case)
#   different       ← backgrounds      (amod)
#   backgrounds     ← students         (nmod)
#   .               ← helpful          (punct)
#   "               ← helpful          (punct)
#   Patient         ← ROOT             (root)
#   :               ← heard            (punct)
#   "               ← heard            (punct)
#   I               ← heard            (nsubj)
#   heard           ← Patient          (appos)
#   about           ← group            (case)
#   that            ← group            (det)
#   group           ← heard            (obl)
#   during          ← orientation      (case)
#   orientation     ← heard            (obl)
#   ,               ← joined           (punct)
#   but             ← joined           (cc)
#   I               ← joined           (nsubj)
#   have            ← joined           (aux)
#   n’t             ← joined           (advmod)
#   joined          ← heard            (conj)
#   .               ← Patient          (punct)
#   I               ← worry            (nsubj)
#   worry           ← ROOT             (root)
#   my              ← schedule         (nmod:poss)
#   schedule        ← allow            (nsubj)
#   wo              ← allow            (aux)
#   n’t             ← allow            (advmod)
#   allow           ← worry            (ccomp)
#   it              ← allow            (obj)
#   ,               ← and              (punct)
#   and             ← sure             (cc)
#   honestly        ← sure             (advmod)
#   ,               ← honestly         (punct)
#   I               ← sure             (nsubj)
#   ’m              ← sure             (cop)
#   not             ← sure             (advmod)
#   sure            ← worry            (conj)
#   if              ← help             (mark)
#   talking         ← help             (csubj)
#   will            ← help             (aux)
#   help            ← sure             (ccomp)
#   .               ← worry            (punct)
#   "               ← worry            (punct)
#   Therapist       ← ROOT             (root)
#   :               ← spoken           (punct)
#   "               ← spoken           (punct)
#   Have            ← spoken           (aux)
#   you             ← spoken           (nsubj)
#   spoken          ← Therapist        (appos)
#   with            ← doctor           (case)
#   your            ← doctor           (nmod:poss)
#   primary         ← doctor           (amod)
#   care            ← doctor           (compound)
#   doctor          ← spoken           (obl)
#   at              ← Hospital         (case)
#   Newton          ← Hospital         (compound)
#   General         ← Hospital         (amod)
#   Hospital        ← doctor           (nmod)
#   about           ← symptoms         (case)
#   these           ← symptoms         (det)
#   symptoms        ← spoken           (obl)
#   ?               ← Therapist        (punct)
#   Also            ← are              (advmod)
#   ,               ← Also             (punct)
#   are             ← ROOT             (root)
#   there           ← are              (expl)
#   any             ← conditions       (det)
#   other           ← conditions       (amod)
#   medical         ← conditions       (amod)
#   conditions      ← are              (nsubj)
#   in              ← history          (case)
#   your            ← history          (nmod:poss)
#   family          ← history          (compound)
#   history         ← conditions       (nmod)
#   ?               ← are              (punct)
#   "               ← are              (punct)
#   Patient         ← ROOT             (root)
#   :               ← has              (punct)
#   "               ← has              (punct)
#   My              ← mom              (nmod:poss)
#   mom             ← side             (nmod:poss)
#   ’s              ← mom              (case)
#   side            ← has              (nsubj)
#   has             ← Patient          (appos)
#   a               ← history          (det)
#   history         ← has              (obj)
#   of              ← migraine         (case)
#   migraine        ← history          (nmod)
#   and             ← insomnia         (cc)
#   insomnia        ← migraine         (conj)
#   ,               ← think            (punct)
#   but             ← think            (cc)
#   I               ← think            (nsubj)
#   do              ← think            (aux)
#   n’t             ← think            (advmod)
#   think           ← has              (conj)
#   anyone          ← had              (nsubj)
#   ’s              ← had              (aux)
#   had             ← think            (ccomp)
#   anxiety         ← had              (obj)
#   like            ← this             (case)
#   this            ← anxiety          (nmod)
#   .               ← Patient          (punct)
#   Robyn           ← suggested        (nsubj)
#   suggested       ← ROOT             (root)
#   I               ← journal          (nsubj)
#   journal         ← suggested        (ccomp)
#   my              ← symptoms         (nmod:poss)
#   symptoms        ← journal          (obj)
#   and             ← use              (cc)
#   use             ← journal          (conj)
#   the             ← app              (det)
#   meditation      ← app              (compound)
#   app             ← use              (obj)
#   she             ← downloaded       (nsubj)
#   downloaded      ← app              (acl:relcl)
#   on              ← phone            (case)
#   my              ← phone            (nmod:poss)
#   phone           ← downloaded       (obl)
#   .               ← suggested        (punct)
#   "               ← suggested        (punct)
#   Therapist       ← ROOT             (root)
#   :               ← Let              (punct)
#   "               ← Let              (punct)
#   Let             ← Therapist        (appos)
#   ’s              ← Let              (obj)
#   try             ← Let              (xcomp)
#   some            ← steps            (det)
#   practical       ← steps            (amod)
#   steps           ← try              (obj)
#   :               ← keep             (punct)
#   keep            ← Let              (parataxis)
#   a               ← log              (det)
#   daily           ← log              (amod)
#   log             ← keep             (obj)
#   of              ← headaches        (case)
#   your            ← headaches        (nmod:poss)
#   headaches       ← log              (nmod)
#   and             ← patterns         (cc)
#   sleep           ← patterns         (compound)
#   patterns        ← headaches        (conj)
#   ,               ← consider         (punct)
#   consider        ← keep             (conj)
#   meeting         ← consider         (xcomp)
#   with            ← group            (case)
#   the             ← group            (det)
#   freshman        ← group            (compound)
#   group           ← meeting          (obl)
#   ,               ← follow           (punct)
#   and             ← follow           (cc)
#   follow          ← keep             (conj)
#   up              ← follow           (compound:prt)
#   with            ← me               (case)
#   me              ← follow           (obl)
#   in              ← weeks            (case)
#   two             ← weeks            (nummod)
#   weeks           ← follow           (obl)
#   .               ← Therapist        (punct)
#   If              ← worsen           (mark)
#   symptoms        ← worsen           (nsubj)
#   worsen          ← discuss          (advcl)
#   ,               ← worsen           (punct)
#   we              ← discuss          (nsubj)
#   can             ← discuss          (aux)
#   discuss         ← ROOT             (root)
#   medication      ← options          (compound)
#   options         ← discuss          (obj)
#   like            ← Zoloft           (case)
#   Zoloft          ← options          (nmod)
#   or              ← Lexapro          (cc)
#   Lexapro         ← Zoloft           (conj)
#   at              ← appointment      (case)
#   your            ← appointment      (nmod:poss)
#   next            ← appointment      (amod)
#   appointment     ← discuss          (obl)
#   .               ← discuss          (punct)
#   "               ← discuss          (punct)
#
# -- Constituency Parse --
# (ROOT (NP (NP (NN Patient)) (: :) (`` ") (NP (UH Hi) (NNP Dr.) (NNP Carter)) (. .)))
# (ROOT (S (S (NP (PRP$ My) (NN name)) (VP (VBZ is) (NP (NNP Sarah)))) (, ,) (NP (PRP I)) (VP (VBP ’m) (ADVP (RB here)) (SBAR (IN because) (S (NP (PRP I)) (VP (VBP ’ve) (VP (VBN been) (VP (VBG struggling) (PP (IN with) (NP (NN anxiety) (CC and) (NN depression))) (PP (IN since) (S (VP (VBG starting) (PP (IN at) (NP (NNP Newton) (NNP University))) (PP (IN in) (NP (NNP September)))))))))))) (. .) ('' ")))
# (ROOT (NP (NP (NN Therapist)) (: :) (NP (S (NP (`` ") (JJ Nice)) (S (VP (TO to) (VP (VB meet) (NP (PRP you)))))) (, ,) (NP (NNP Sarah))) (. .)))
# (ROOT (S (NP (PRP I)) (VP (VBP ’m) (NP (NP (NNP Dr.) (NNP Carter)) (, ,) (NP (NP (DT a) (NN psychiatrist)) (PP (IN at) (NP (DT the) (NNP Boston) (NML (NNP Mind) (NNP Health)) (NNP Center)))))) (. .)))
# (ROOT (SQ (MD Can) (NP (PRP you)) (VP (VB tell) (NP (PRP me)) (NP (NP (JJR more)) (PP (IN about) (NP (PRP$ your) (NNS symptoms))))) (. ?) ('' ")))
# (ROOT (NP (NP (NN Patient)) (: :) (`` ") (S (S (ADVP (RB Mostly)) (NP (PRP I)) (VP (VBP feel) (NP (JJ constant) (NN fatigue)))) (, ,) (CC and) (S (NP (PRP I)) (VP (VBP ’ve) (VP (VBN had) (NP (NNS headaches)) (NP (DT every) (NN morning)) (PP (IN since) (NP (NP (DT the) (NNP Halloween) (NN event)) (PP (IN on) (NP (NN campus))))))))) (. .)))
# (ROOT (S (S (NP (NP (PRP$ My) (NN mom)) (, ,) (NP (NNP Robyn)) (, ,)) (VP (VBZ is) (ADJP (JJ worried)) (SBAR (IN because) (S (NP (PRP she)) (VP (VBZ thinks) (SBAR (S (NP (PRP I)) (VP (MD might) (VP (VB need) (NP (NNP Zoloft) (CC or) (NNP Lexapro))))))))))) (, ,) (CC but) (S (NP (PRP I)) (VP (VBP have) (ADVP (RB n’t)) (VP (VBN tried) (ADVP (DT either))))) (. .) ('' ")))
# (ROOT (NP (NP (NN Therapist)) (: :) (`` ") (S (NP (NP (PRP It))) (VP (VBZ ’s) (ADJP (JJ understandable)) (S (VP (TO to) (VP (VB feel) (ADJP (VBN overwhelmed)) (, ,) (PP (ADVP (RB especially)) (IN with) (NP (NP (PRP$ your) (NN course) (NN load)) (CC and) (NP (NP (DT the) (NN transition)) (PP (IN to) (NP (NN university) (NN life))))))))))) (. .)))
# (ROOT (SQ (VBP Are) (NP (PRP you)) (ADVP (RB currently)) (VP (VBG taking) (NP (DT any) (NN medication) (CC or) (NNS supplements))) (. ?) ('' ")))
# (ROOT (NP (NP (NN Patient)) (: :) (`` ") (S (S (NP (PRP I)) (VP (VBD tried) (NP (NNP Tylenol) (CC and) (NNP Advil)) (PP (IN for) (NP (DT the) (NNS headaches))))) (, ,) (CC but) (S (NP (PRP they)) (VP (VBP do) (ADVP (RB n’t)) (VP (VB help))))) (. .)))
# (ROOT (S (S (NP (PRP I)) (ADVP (RB also)) (VP (VBD bought) (NP (NP (DT a) (JJ new) (NN sleep) (NN tracker)) (CC and) (NP (DT some) (ADJP (NN noise) (HYPH -) (VBG cancelling)) (NNS headphones))))) (, ,) (CC but) (S (NP (NN nothing)) (VP (VBZ seems) (S (VP (TO to) (VP (VB make) (NP (DT a) (NN difference))))))) (. .) ('' ")))
# (ROOT (NP (NN Therapist) (: :) (`` ") (SQ (VBP Have) (NP (PRP you)) (VP (VBN considered) (S (VP (VBG attending) (NP (DT the) (JJ wellness) (NN group)) (PP (IN for) (NP (NNS freshmen))))))) (. ?)))
# (ROOT (S (ADVP (RB Sometimes)) (S (VP (VBG talking) (PP (IN to) (NP (NNS peers))) (PP (IN with) (NP (JJ similar) (NNS experiences))))) (VP (MD can) (VP (VB be) (ADJP (JJ helpful)) (, ,) (PP (ADVP (RB especially)) (IN for) (NP (NP (NNS students)) (PP (IN from) (NP (JJ different) (NNS backgrounds))))))) (. .) ('' ")))
# (ROOT (NP (NP (NN Patient)) (: :) (`` ") (S (S (NP (PRP I)) (VP (VBD heard) (PP (IN about) (NP (DT that) (NN group))) (PP (IN during) (NP (NN orientation))))) (, ,) (CC but) (S (NP (PRP I)) (VP (VBP have) (ADVP (RB n’t)) (VP (VBN joined))))) (. .)))
# (ROOT (S (NP (PRP I)) (VP (VBP worry) (SBAR (S (S (NP (PRP$ my) (NN schedule)) (VP (MD wo) (ADVP (RB n’t)) (VP (VB allow) (NP (PRP it))))) (, ,) (CC and) (ADVP (RB honestly)) (, ,) (NP (PRP I)) (VP (VBP ’m) (RB not) (ADJP (JJ sure) (SBAR (IN if) (S (VP (VBG talking) (VP (MD will) (VP (VB help))))))))))) (. .) ('' ")))
# (ROOT (NP (NN Therapist) (: :) (`` ") (SQ (VBP Have) (NP (PRP you)) (VP (VBN spoken) (PP (IN with) (NP (NP (PRP$ your) (NML (JJ primary) (NN care)) (NN doctor)) (PP (IN at) (NP (NNP Newton) (NNP General) (NNP Hospital))) (PP (IN about) (NP (DT these) (NNS symptoms))))))) (. ?)))
# (ROOT (SQ (ADVP (RB Also)) (, ,) (VBP are) (NP (EX there)) (NP (NP (DT any) (JJ other) (JJ medical) (NNS conditions)) (PP (IN in) (NP (PRP$ your) (NN family) (NN history)))) (. ?) ('' ")))
# (ROOT (NP (NP (NN Patient)) (: :) (`` ") (S (S (NP (NP (PRP$ My) (NN mom)) (NP (POS ’s) (NN side))) (VP (VBZ has) (NP (NP (DT a) (NN history)) (PP (IN of) (NP (NN migraine) (CC and) (NN insomnia)))))) (, ,) (CC but) (S (NP (PRP I)) (VP (VBP do) (ADVP (RB n’t)) (VP (VB think) (SBAR (S (NP (NN anyone)) (VP (VBZ ’s) (VP (VBN had) (NP (NN anxiety)) (PP (IN like) (NP (DT this))))))))))) (. .)))
# (ROOT (S (NP (NNP Robyn)) (VP (VBD suggested) (SBAR (S (NP (PRP I)) (VP (VP (VBP journal) (NP (PRP$ my) (NNS symptoms))) (CC and) (VP (VBP use) (NP (NP (DT the) (NN meditation) (NN app)) (SBAR (S (NP (PRP she)) (VP (VBD downloaded) (PP (IN on) (NP (PRP$ my) (NN phone)))))))))))) (. .) ('' ")))
# (ROOT (NP (NP (NN Therapist)) (: :) (`` ") (S (S (VP (VB Let) (S (NP (PRP ’s)) (VP (VB try) (NP (DT some) (JJ practical) (NNS steps)))))) (: :) (S (VP (VP (VB keep) (NP (NP (DT a) (JJ daily) (NN log)) (PP (IN of) (NP (PRP$ your) (NML (NNS headaches) (CC and) (NN sleep)) (NNS patterns))))) (, ,) (VP (VB consider) (S (VP (VBG meeting) (PP (IN with) (NP (DT the) (NN freshman) (NN group)))))) (, ,) (CC and) (VP (VB follow) (PRT (RP up)) (PP (IN with) (NP (PRP me))) (PP (IN in) (NP (CD two) (NNS weeks))))))) (. .)))
# (ROOT (S (SBAR (IN If) (S (NP (NNS symptoms)) (VP (VBP worsen)))) (, ,) (NP (PRP we)) (VP (MD can) (VP (VB discuss) (NP (NP (NN medication) (NNS options)) (PP (IN like) (NP (NP (NNP Zoloft)) (CC or) (NP (NNP Lexapro))))) (PP (IN at) (NP (PRP$ your) (JJ next) (NN appointment))))) (. .) ('' ")))
#
# ==============================
# BIOMEDICAL NER (BC5CDR)
#  ==============================
# -- Named Entities --
#   anxiety                         (DISEASE)
#   depression                      (DISEASE)
#   fatigue                         (DISEASE)
#   headaches                       (DISEASE)
#   Tylenol                         (CHEMICAL)
#   headaches                       (DISEASE)
#   migraine                        (DISEASE)
#   insomnia                        (DISEASE)
#   anxiety                         (DISEASE)
#   headaches                       (DISEASE)

# %% [markdown]
# # Cell 4: Split text into utterances (by speaker, crude version)

# %%
import re

# Updated pattern: start-of-line (^) match, no lookbehind needed!
utterance_pattern = re.compile(r'^(Patient|Therapist):\s*"([^"]+)"', re.MULTILINE)
utterances = []
for match in utterance_pattern.finditer(text):
    speaker = match.group(1).lower()
    utt_text = match.group(2).strip()
    if utt_text:
        utterances.append({"speaker": speaker, "text": utt_text})

# Sanity check
for i, utt in enumerate(utterances):
    print(f"[{i}] {utt['speaker'].capitalize()}: {utt['text']}")
# Out:
# [0] Patient: Hi Dr. Carter. My name is Sarah, I’m here because I’ve been struggling with anxiety and depression since starting at Newton University in September.
# [1] Therapist: Nice to meet you, Sarah. I’m Dr. Carter, a psychiatrist at the Boston Mind Health Center. Can you tell me more about your symptoms?
# [2] Patient: Mostly I feel constant fatigue, and I’ve had headaches every morning since the Halloween event on campus. My mom, Robyn, is worried because she thinks I might need Zoloft or Lexapro, but I haven’t tried either.
# [3] Therapist: It’s understandable to feel overwhelmed, especially with your course load and the transition to university life. Are you currently taking any medication or supplements?
# [4] Patient: I tried Tylenol and Advil for the headaches, but they don’t help. I also bought a new sleep tracker and some noise-cancelling headphones, but nothing seems to make a difference.
# [5] Therapist: Have you considered attending the wellness group for freshmen? Sometimes talking to peers with similar experiences can be helpful, especially for students from different backgrounds.
# [6] Patient: I heard about that group during orientation, but I haven’t joined. I worry my schedule won’t allow it, and honestly, I’m not sure if talking will help.
# [7] Therapist: Have you spoken with your primary care doctor at Newton General Hospital about these symptoms? Also, are there any other medical conditions in your family history?
# [8] Patient: My mom’s side has a history of migraine and insomnia, but I don’t think anyone’s had anxiety like this. Robyn suggested I journal my symptoms and use the meditation app she downloaded on my phone.
# [9] Therapist: Let’s try some practical steps: keep a daily log of your headaches and sleep patterns, consider meeting with the freshman group, and follow up with me in two weeks. If symptoms worsen, we can discuss medication options like Zoloft or Lexapro at your next appointment.

# %% [markdown]
# # Cell 5: Build Clipboard dictionary (prototype)

# %%
from collections import defaultdict

def build_clipboard_dict(doc_en, doc_bc5cdr, utterances):
    clipboard = {"named_entities": {}, "dependency_relations": []}
    entity_index = {}

    # Biomedical first (higher priority)
    for ent in doc_bc5cdr.ents:
        entity_index[ent.text] = {"label": ent.type, "source": "bc5cdr"}

    # Add generic entities if not already in
    for ent in doc_en.ents:
        if ent.text not in entity_index:
            entity_index[ent.text] = {"label": ent.type, "source": "en"}

    # Map entity to utterances
    for i, utt in enumerate(utterances):
        for ent_text, info in entity_index.items():
            if ent_text in utt['text']:
                if ent_text not in clipboard["named_entities"]:
                    clipboard["named_entities"][ent_text] = {
                        "type": info["label"],
                        "source": info["source"],
                        "timestamps": [i],
                        "FirstInstance": {
                            "utterance_id": i,
                            "speaker": utt["speaker"],
                            "rawText": utt["text"],
                            "han_vector": "[HAN vector placeholder]"
                        },
                        "LatestInstance": {
                            "utterance_id": i,
                            "speaker": utt["speaker"],
                            "rawText": utt["text"],
                            "han_vector": "[HAN vector placeholder]"
                        }
                    }
                else:
                    clipboard["named_entities"][ent_text]["timestamps"].append(i)
                    clipboard["named_entities"][ent_text]["LatestInstance"] = {
                        "utterance_id": i,
                        "speaker": utt["speaker"],
                        "rawText": utt["text"],
                        "han_vector": "[HAN vector placeholder]"
                    }

    # Dependency relations (sentence-level)
    for i, sent in enumerate(doc_en.sentences):
        for word in sent.words:
            if word.deprel in ("nsubj", "obj"):
                subj = word.text if word.deprel == "nsubj" else None
                obj = word.text if word.deprel == "obj" else None
                verb = sent.words[word.head-1].text if word.head > 0 else None
                if subj and verb:
                    clipboard["dependency_relations"].append(
                        {"subj": subj, "verb": verb, "obj": obj, "timestamp": i}
                    )
    return clipboard

# Actually build it
clipboard = build_clipboard_dict(doc_en, doc_bc5cdr, utterances)

# %% [markdown]
# # Cell 6: Pretty-print the Clipboard

# %%
import json

def print_clipboard(clipboard):
    print("\n\n=== Named Entities ===\n")
    for ent, info in clipboard["named_entities"].items():
        print(f"{ent!r} ({info['type']}, {info['source']})")
        print(f"  Timestamps: {info['timestamps']}")
        print(f"  FirstInstance: [{info['FirstInstance']['speaker']}] {info['FirstInstance']['rawText']}")
        print(f"  LatestInstance: [{info['LatestInstance']['speaker']}] {info['LatestInstance']['rawText']}")
        print("")
    # print("\n=== Dependency Relations ===\n")
    # for rel in clipboard["dependency_relations"]:
    #     print(f"  subj: {rel['subj']}, verb: {rel['verb']}, obj: {rel['obj']}, t={rel['timestamp']}")

# Show output
print_clipboard(clipboard)
# Out:
# === Named Entities ===
#
# 'anxiety' (DISEASE, bc5cdr)
#   Timestamps: [0, 8]
#   FirstInstance: [patient] Hi Dr. Carter. My name is Sarah, I’m here because I’ve been struggling with anxiety and depression since starting at Newton University in September.
#   LatestInstance: [patient] My mom’s side has a history of migraine and insomnia, but I don’t think anyone’s had anxiety like this. Robyn suggested I journal my symptoms and use the meditation app she downloaded on my phone.
#
# 'depression' (DISEASE, bc5cdr)
#   Timestamps: [0]
#   FirstInstance: [patient] Hi Dr. Carter. My name is Sarah, I’m here because I’ve been struggling with anxiety and depression since starting at Newton University in September.
#   LatestInstance: [patient] Hi Dr. Carter. My name is Sarah, I’m here because I’ve been struggling with anxiety and depression since starting at Newton University in September.
#
# 'Carter' (PERSON, en)
#   Timestamps: [0, 1]
#   FirstInstance: [patient] Hi Dr. Carter. My name is Sarah, I’m here because I’ve been struggling with anxiety and depression since starting at Newton University in September.
#   LatestInstance: [therapist] Nice to meet you, Sarah. I’m Dr. Carter, a psychiatrist at the Boston Mind Health Center. Can you tell me more about your symptoms?
#
# 'Sarah' (PERSON, en)
#   Timestamps: [0, 1]
#   FirstInstance: [patient] Hi Dr. Carter. My name is Sarah, I’m here because I’ve been struggling with anxiety and depression since starting at Newton University in September.
#   LatestInstance: [therapist] Nice to meet you, Sarah. I’m Dr. Carter, a psychiatrist at the Boston Mind Health Center. Can you tell me more about your symptoms?
#
# 'Newton University' (ORG, en)
#   Timestamps: [0]
#   FirstInstance: [patient] Hi Dr. Carter. My name is Sarah, I’m here because I’ve been struggling with anxiety and depression since starting at Newton University in September.
#   LatestInstance: [patient] Hi Dr. Carter. My name is Sarah, I’m here because I’ve been struggling with anxiety and depression since starting at Newton University in September.
#
# 'September' (DATE, en)
#   Timestamps: [0]
#   FirstInstance: [patient] Hi Dr. Carter. My name is Sarah, I’m here because I’ve been struggling with anxiety and depression since starting at Newton University in September.
#   LatestInstance: [patient] Hi Dr. Carter. My name is Sarah, I’m here because I’ve been struggling with anxiety and depression since starting at Newton University in September.
#
# 'the Boston Mind Health Center' (ORG, en)
#   Timestamps: [1]
#   FirstInstance: [therapist] Nice to meet you, Sarah. I’m Dr. Carter, a psychiatrist at the Boston Mind Health Center. Can you tell me more about your symptoms?
#   LatestInstance: [therapist] Nice to meet you, Sarah. I’m Dr. Carter, a psychiatrist at the Boston Mind Health Center. Can you tell me more about your symptoms?
#
# 'fatigue' (DISEASE, bc5cdr)
#   Timestamps: [2]
#   FirstInstance: [patient] Mostly I feel constant fatigue, and I’ve had headaches every morning since the Halloween event on campus. My mom, Robyn, is worried because she thinks I might need Zoloft or Lexapro, but I haven’t tried either.
#   LatestInstance: [patient] Mostly I feel constant fatigue, and I’ve had headaches every morning since the Halloween event on campus. My mom, Robyn, is worried because she thinks I might need Zoloft or Lexapro, but I haven’t tried either.
#
# 'headaches' (DISEASE, bc5cdr)
#   Timestamps: [2, 4, 9]
#   FirstInstance: [patient] Mostly I feel constant fatigue, and I’ve had headaches every morning since the Halloween event on campus. My mom, Robyn, is worried because she thinks I might need Zoloft or Lexapro, but I haven’t tried either.
#   LatestInstance: [therapist] Let’s try some practical steps: keep a daily log of your headaches and sleep patterns, consider meeting with the freshman group, and follow up with me in two weeks. If symptoms worsen, we can discuss medication options like Zoloft or Lexapro at your next appointment.
#
# 'Halloween' (DATE, en)
#   Timestamps: [2]
#   FirstInstance: [patient] Mostly I feel constant fatigue, and I’ve had headaches every morning since the Halloween event on campus. My mom, Robyn, is worried because she thinks I might need Zoloft or Lexapro, but I haven’t tried either.
#   LatestInstance: [patient] Mostly I feel constant fatigue, and I’ve had headaches every morning since the Halloween event on campus. My mom, Robyn, is worried because she thinks I might need Zoloft or Lexapro, but I haven’t tried either.
#
# 'Robyn' (PERSON, en)
#   Timestamps: [2, 8]
#   FirstInstance: [patient] Mostly I feel constant fatigue, and I’ve had headaches every morning since the Halloween event on campus. My mom, Robyn, is worried because she thinks I might need Zoloft or Lexapro, but I haven’t tried either.
#   LatestInstance: [patient] My mom’s side has a history of migraine and insomnia, but I don’t think anyone’s had anxiety like this. Robyn suggested I journal my symptoms and use the meditation app she downloaded on my phone.
#
# 'Lexapro' (PRODUCT, en)
#   Timestamps: [2, 9]
#   FirstInstance: [patient] Mostly I feel constant fatigue, and I’ve had headaches every morning since the Halloween event on campus. My mom, Robyn, is worried because she thinks I might need Zoloft or Lexapro, but I haven’t tried either.
#   LatestInstance: [therapist] Let’s try some practical steps: keep a daily log of your headaches and sleep patterns, consider meeting with the freshman group, and follow up with me in two weeks. If symptoms worsen, we can discuss medication options like Zoloft or Lexapro at your next appointment.
#
# 'Zoloft' (PRODUCT, en)
#   Timestamps: [2, 9]
#   FirstInstance: [patient] Mostly I feel constant fatigue, and I’ve had headaches every morning since the Halloween event on campus. My mom, Robyn, is worried because she thinks I might need Zoloft or Lexapro, but I haven’t tried either.
#   LatestInstance: [therapist] Let’s try some practical steps: keep a daily log of your headaches and sleep patterns, consider meeting with the freshman group, and follow up with me in two weeks. If symptoms worsen, we can discuss medication options like Zoloft or Lexapro at your next appointment.
#
# 'Tylenol' (CHEMICAL, bc5cdr)
#   Timestamps: [4]
#   FirstInstance: [patient] I tried Tylenol and Advil for the headaches, but they don’t help. I also bought a new sleep tracker and some noise-cancelling headphones, but nothing seems to make a difference.
#   LatestInstance: [patient] I tried Tylenol and Advil for the headaches, but they don’t help. I also bought a new sleep tracker and some noise-cancelling headphones, but nothing seems to make a difference.
#
# 'Newton General Hospital' (FAC, en)
#   Timestamps: [7]
#   FirstInstance: [therapist] Have you spoken with your primary care doctor at Newton General Hospital about these symptoms? Also, are there any other medical conditions in your family history?
#   LatestInstance: [therapist] Have you spoken with your primary care doctor at Newton General Hospital about these symptoms? Also, are there any other medical conditions in your family history?
#
# 'migraine' (DISEASE, bc5cdr)
#   Timestamps: [8]
#   FirstInstance: [patient] My mom’s side has a history of migraine and insomnia, but I don’t think anyone’s had anxiety like this. Robyn suggested I journal my symptoms and use the meditation app she downloaded on my phone.
#   LatestInstance: [patient] My mom’s side has a history of migraine and insomnia, but I don’t think anyone’s had anxiety like this. Robyn suggested I journal my symptoms and use the meditation app she downloaded on my phone.
#
# 'insomnia' (DISEASE, bc5cdr)
#   Timestamps: [8]
#   FirstInstance: [patient] My mom’s side has a history of migraine and insomnia, but I don’t think anyone’s had anxiety like this. Robyn suggested I journal my symptoms and use the meditation app she downloaded on my phone.
#   LatestInstance: [patient] My mom’s side has a history of migraine and insomnia, but I don’t think anyone’s had anxiety like this. Robyn suggested I journal my symptoms and use the meditation app she downloaded on my phone.
#
# 'two weeks' (DATE, en)
#   Timestamps: [9]
#   FirstInstance: [therapist] Let’s try some practical steps: keep a daily log of your headaches and sleep patterns, consider meeting with the freshman group, and follow up with me in two weeks. If symptoms worsen, we can discuss medication options like Zoloft or Lexapro at your next appointment.
#   LatestInstance: [therapist] Let’s try some practical steps: keep a daily log of your headaches and sleep patterns, consider meeting with the freshman group, and follow up with me in two weeks. If symptoms worsen, we can discuss medication options like Zoloft or Lexapro at your next appointment.
