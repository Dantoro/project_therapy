# %% [markdown]
# Emotion Classifier

# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 200)

import json
from typing import List, Dict, Union

# %% [markdown]
# ## Reading in the Data

# %%
# Load emotion names from file
with open('../datasets/GoEmotions/emotions.txt', 'r') as f:
    emotion_names = [line.strip() for line in f]

# Function to read and expand one file
def load_go_emotions_split(path):
    df = pd.read_csv(path, sep='\t', header=None, names=['text', 'emotion_labels', 'id'])
    # Create 28 one-hot columns, all default to 0
    for i, emo in enumerate(emotion_names):
        df[emo] = 0
    # Fill columns by parsing emotion_labels
    for idx, row in df.iterrows():
        label_idxs = list(map(int, row['emotion_labels'].split(',')))
        for label in label_idxs:
            df.at[idx, emotion_names[label]] = 1
    return df

# Load all splits
go_emotions_train = load_go_emotions_split('../datasets/GoEmotions/train.tsv')
go_emotions_val   = load_go_emotions_split('../datasets/GoEmotions/dev.tsv')
go_emotions_test  = load_go_emotions_split('../datasets/GoEmotions/test.tsv')

# Read in the Ekman mapping
with open('../datasets/GoEmotions/ekman_mapping.json', 'r') as f:
    ekman_map = json.load(f)

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# ### Ekman Mapping

# %%
def ekman_category_breakdown(
    df: pd.DataFrame,
    emotion_columns: list,
    ekman_mapping: dict
) -> None:
    """
    Prints a clean percentage breakdown of each Ekman umbrella category in the dataset.

    Args:
        df (pd.DataFrame): DataFrame with one-hot columns for emotions.
        emotion_columns (list): List of the 28 emotion column names.
        ekman_mapping (dict): Dict mapping Ekman categories to emotion names.
    """
    total = len(df)
    print("Ekman category percentage breakdown:")
    for ekman_cat, fine_emotions in ekman_mapping.items():
        present = df[fine_emotions].any(axis=1)
        pct = present.sum() / total * 100
        print(f"{ekman_cat:<9} : {pct:.2f}%")

# %% [markdown]
# ### Text Stats

# %%
def text_length_stats(
    df: pd.DataFrame,
    text_col: str = "text",
    by: str = "char",
    return_df: bool = False
):
    """
    Print a neatly aligned stats table for lengths of the text column (char or word count).

    Args:
        df (pd.DataFrame): DataFrame with the text data.
        text_col (str): Column name containing text. Default 'text'.
        by (str): 'char' for character count, 'word' for word count.
        return_df (bool): If True, also return the stats as a DataFrame.

    Returns:
        Optional[pd.DataFrame]: Stats DataFrame if requested.
    """
    if by == "char":
        lengths = df[text_col].astype(str).apply(len)
    elif by == "word":
        lengths = df[text_col].astype(str).apply(lambda x: len(x.split()))
    else:
        raise ValueError("`by` must be 'char' or 'word'")

    stats = [
        ("count",        lengths.count()),
        ("min",          lengths.min()),
        ("Q1",           lengths.quantile(0.25)),
        ("median",       lengths.median()),
        ("mean",         lengths.mean()),
        ("Q3",           lengths.quantile(0.75)),
        ("max",          lengths.max()),
        ("mode",         lengths.mode().values[0] if not lengths.mode().empty else None),
        ("std dev",      lengths.std()),
        ("variance",     lengths.var()),
        ("IQR",          lengths.quantile(0.75) - lengths.quantile(0.25)),
    ]
    print(f"\n{'Text length statistics (' + ('characters' if by=='char' else 'words') + ')':^36}")
    print("=" * 36)
    for label, val in stats:
        print(f"{label:<10}: {val:>10.2f}" if isinstance(val, float) else f"{label:<10}: {val:>10}")
    if return_df:
        return pd.DataFrame(stats, columns=["statistic", "value"]).set_index("statistic")

10, #T_93b0f_row3_col11, #T_93b0f_row3_col12, #T_93b0f_row3_col13, #T_93b0f_row3_col14, #T_93b0f_row3_col15, #T_93b0f_row3_col16, #T_93b0f_row3_col17, #T_93b0f_row3_col18, #T_93b0f_row3_col19, #T_93b0f_row3_col20, #T_93b0f_row3_col21, #T_93b0f_row3_col22, #T_93b0f_row3_col23, #T_93b0f_row3_col24, #T_93b0f_row3_col25, #T_93b0f_row3_col26, #T_93b0f_row3_col27, #T_93b0f_row3_col28, #T_93b0f_row3_col29, #T_93b0f_row3_col30, #T_93b0f_row4_col0, #T_93b0f_row4_col1, #T_93b0f_row4_col2, #T_93b0f_row4_col3, #T_93b0f_row4_col4, #T_93b0f_row4_col5, #T_93b0f_row4_col6, #T_93b0f_row4_col7, #T_93b0f_row4_col8, #T_93b0f_row4_col9, #T_93b0f_row4_col10, #T_93b0f_row4_col11, #T_93b0f_row4_col12, #T_93b0f_row4_col13, #T_93b0f_row4_col14, #T_93b0f_row4_col15, #T_93b0f_row4_col16, #T_93b0f_row4_col17, #T_93b0f_row4_col18, #T_93b0f_row4_col19, #T_93b0f_row4_col20, #T_93b0f_row4_col21, #T_93b0f_row4_col22, #T_93b0f_row4_col23, #T_93b0f_row4_col24, #T_93b0f_row4_col25, #T_93b0f_row4_col26, #T_93b0f_row4_col27, #T_93b0f_row4_col28, #T_93b0f_row4_col29, #T_93b0f_row4_col30 {
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_93b0f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93b0f_level0_col0" class="col_heading level0 col0" >text</th>
#       <th id="T_93b0f_level0_col1" class="col_heading level0 col1" >emotion_labels</th>
#       <th id="T_93b0f_level0_col2" class="col_heading level0 col2" >id</th>
#       <th id="T_93b0f_level0_col3" class="col_heading level0 col3" >admiration</th>
#       <th id="T_93b0f_level0_col4" class="col_heading level0 col4" >amusement</th>
#       <th id="T_93b0f_level0_col5" class="col_heading level0 col5" >anger</th>
#       <th id="T_93b0f_level0_col6" class="col_heading level0 col6" >annoyance</th>
#       <th id="T_93b0f_level0_col7" class="col_heading level0 col7" >approval</th>
#       <th id="T_93b0f_level0_col8" class="col_heading level0 col8" >caring</th>
#       <th id="T_93b0f_level0_col9" class="col_heading level0 col9" >confusion</th>
#       <th id="T_93b0f_level0_col10" class="col_heading level0 col10" >curiosity</th>
#       <th id="T_93b0f_level0_col11" class="col_heading level0 col11" >desire</th>
#       <th id="T_93b0f_level0_col12" class="col_heading level0 col12" >disappointment</th>
#       <th id="T_93b0f_level0_col13" class="col_heading level0 col13" >disapproval</th>
#       <th id="T_93b0f_level0_col14" class="col_heading level0 col14" >disgust</th>
#       <th id="T_93b0f_level0_col15" class="col_heading level0 col15" >embarrassment</th>
#       <th id="T_93b0f_level0_col16" class="col_heading level0 col16" >excitement</th>
#       <th id="T_93b0f_level0_col17" class="col_heading level0 col17" >fear</th>
#       <th id="T_93b0f_level0_col18" class="col_heading level0 col18" >gratitude</th>
#       <th id="T_93b0f_level0_col19" class="col_heading level0 col19" >grief</th>
#       <th id="T_93b0f_level0_col20" class="col_heading level0 col20" >joy</th>
#       <th id="T_93b0f_level0_col21" class="col_heading level0 col21" >love</th>
#       <th id="T_93b0f_level0_col22" class="col_heading level0 col22" >nervousness</th>
#       <th id="T_93b0f_level0_col23" class="col_heading level0 col23" >optimism</th>
#       <th id="T_93b0f_level0_col24" class="col_heading level0 col24" >pride</th>
#       <th id="T_93b0f_level0_col25" class="col_heading level0 col25" >realization</th>
#       <th id="T_93b0f_level0_col26" class="col_heading level0 col26" >relief</th>
#       <th id="T_93b0f_level0_col27" class="col_heading level0 col27" >remorse</th>
#       <th id="T_93b0f_level0_col28" class="col_heading level0 col28" >sadness</th>
#       <th id="T_93b0f_level0_col29" class="col_heading level0 col29" >surprise</th>
#       <th id="T_93b0f_level0_col30" class="col_heading level0 col30" >neutral</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93b0f_level0_row0" class="row_heading level0 row0" >29238</th>
#       <td id="T_93b0f_row0_col0" class="data row0 col0" >I mean if he’s into it, sure, whatever. I’m not one to judge. </td>
#       <td id="T_93b0f_row0_col1" class="data row0 col1" >27</td>
#       <td id="T_93b0f_row0_col2" class="data row0 col2" >ednnvsb</td>
#       <td id="T_93b0f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_93b0f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_93b0f_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_93b0f_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_93b0f_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_93b0f_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_93b0f_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_93b0f_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_93b0f_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_93b0f_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_93b0f_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_93b0f_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_93b0f_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_93b0f_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_93b0f_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_93b0f_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_93b0f_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_93b0f_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_93b0f_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_93b0f_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_93b0f_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_93b0f_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_93b0f_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_93b0f_row0_col26" class="data row0 col26" >0</td>
#       <td id="T_93b0f_row0_col27" class="data row0 col27" >0</td>
#       <td id="T_93b0f_row0_col28" class="data row0 col28"

# %%
print("go_emotion_train info:\n")
print(go_emotions_train.info())
# Out:
# go_emotion_train info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43410 entries, 0 to 43409
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   text            43410 non-null  object
#  1   emotion_labels  43410 non-null  object
#  2   id              43410 non-null  object
#  3   admiration      43410 non-null  int64
#  4   amusement       43410 non-null  int64
#  5   anger           43410 non-null  int64
#  6   annoyance       43410 non-null  int64
#  7   approval        43410 non-null  int64
#  8   caring          43410 non-null  int64
#  9   confusion       43410 non-null  int64
#  10  curiosity       43410 non-null  int64
#  11  desire          43410 non-null  int64
#  12  disappointment  43410 non-null  int64
#  13  disapproval     43410 non-null  int64
#  14  disgust         43410 non-null  int64
#  15  embarrassment   43410 non-null  int64
#  16  excitement      43410 non-null  int64
#  17  fear            43410 non-null  int64
#  18  gratitude       43410 non-null  int64
#  19  grief           43410 non-null  int64
#  20  joy             43410 non-null  int64
#  21  love            43410 non-null  int64
#  22  nervousness     43410 non-null  int64
#  23  optimism        43410 non-null  int64
#  24  pride           43410 non-null  int64
#  25  realization     43410 non-null  int64
#  26  relief          43410 non-null  int64
#  27  remorse         43410 non-null  int64
#  28  sadness         43410 non-null  int64
#  29  surprise        43410 non-null  int64
#  30  neutral         43410 non-null  int64
# dtypes: int64(28), object(3)
# memory usage: 10.3+ MB
# None

# %%
ekman_category_breakdown(go_emotions_train, emotion_names, ekman_map)
# Out:
# Ekman category percentage breakdown:
# anger     : 12.85%
# disgust   : 1.83%
# fear      : 1.67%
# joy       : 40.11%
# sadness   : 7.52%
# surprise  : 12.36%

# %%
text_length_stats(go_emotions_train, text_col="text", by="char")
# Out:
# Text length statistics (characters)
# ====================================
# count     :      43410
# min       :          2
# Q1        :      38.00
# median    :      65.00
# mean      :      68.40
# Q3        :      96.00
# max       :        703
# mode      :         56
# std dev   :      36.72
# variance  :    1348.50
# IQR       :      58.00

# %% [markdown]
# # Exploring Validation Set

# %%
print("5 random rows of the validation set:\n")
1a81_row3_col14, #T_b1a81_row3_col15, #T_b1a81_row3_col16, #T_b1a81_row3_col17, #T_b1a81_row3_col18, #T_b1a81_row3_col19, #T_b1a81_row3_col20, #T_b1a81_row3_col21, #T_b1a81_row3_col22, #T_b1a81_row3_col23, #T_b1a81_row3_col24, #T_b1a81_row3_col25, #T_b1a81_row3_col26, #T_b1a81_row3_col27, #T_b1a81_row3_col28, #T_b1a81_row3_col29, #T_b1a81_row3_col30, #T_b1a81_row4_col0, #T_b1a81_row4_col1, #T_b1a81_row4_col2, #T_b1a81_row4_col3, #T_b1a81_row4_col4, #T_b1a81_row4_col5, #T_b1a81_row4_col6, #T_b1a81_row4_col7, #T_b1a81_row4_col8, #T_b1a81_row4_col9, #T_b1a81_row4_col10, #T_b1a81_row4_col11, #T_b1a81_row4_col12, #T_b1a81_row4_col13, #T_b1a81_row4_col14, #T_b1a81_row4_col15, #T_b1a81_row4_col16, #T_b1a81_row4_col17, #T_b1a81_row4_col18, #T_b1a81_row4_col19, #T_b1a81_row4_col20, #T_b1a81_row4_col21, #T_b1a81_row4_col22, #T_b1a81_row4_col23, #T_b1a81_row4_col24, #T_b1a81_row4_col25, #T_b1a81_row4_col26, #T_b1a81_row4_col27, #T_b1a81_row4_col28, #T_b1a81_row4_col29, #T_b1a81_row4_col30 {
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_b1a81">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1a81_level0_col0" class="col_heading level0 col0" >text</th>
#       <th id="T_b1a81_level0_col1" class="col_heading level0 col1" >emotion_labels</th>
#       <th id="T_b1a81_level0_col2" class="col_heading level0 col2" >id</th>
#       <th id="T_b1a81_level0_col3" class="col_heading level0 col3" >admiration</th>
#       <th id="T_b1a81_level0_col4" class="col_heading level0 col4" >amusement</th>
#       <th id="T_b1a81_level0_col5" class="col_heading level0 col5" >anger</th>
#       <th id="T_b1a81_level0_col6" class="col_heading level0 col6" >annoyance</th>
#       <th id="T_b1a81_level0_col7" class="col_heading level0 col7" >approval</th>
#       <th id="T_b1a81_level0_col8" class="col_heading level0 col8" >caring</th>
#       <th id="T_b1a81_level0_col9" class="col_heading level0 col9" >confusion</th>
#       <th id="T_b1a81_level0_col10" class="col_heading level0 col10" >curiosity</th>
#       <th id="T_b1a81_level0_col11" class="col_heading level0 col11" >desire</th>
#       <th id="T_b1a81_level0_col12" class="col_heading level0 col12" >disappointment</th>
#       <th id="T_b1a81_level0_col13" class="col_heading level0 col13" >disapproval</th>
#       <th id="T_b1a81_level0_col14" class="col_heading level0 col14" >disgust</th>
#       <th id="T_b1a81_level0_col15" class="col_heading level0 col15" >embarrassment</th>
#       <th id="T_b1a81_level0_col16" class="col_heading level0 col16" >excitement</th>
#       <th id="T_b1a81_level0_col17" class="col_heading level0 col17" >fear</th>
#       <th id="T_b1a81_level0_col18" class="col_heading level0 col18" >gratitude</th>
#       <th id="T_b1a81_level0_col19" class="col_heading level0 col19" >grief</th>
#       <th id="T_b1a81_level0_col20" class="col_heading level0 col20" >joy</th>
#       <th id="T_b1a81_level0_col21" class="col_heading level0 col21" >love</th>
#       <th id="T_b1a81_level0_col22" class="col_heading level0 col22" >nervousness</th>
#       <th id="T_b1a81_level0_col23" class="col_heading level0 col23" >optimism</th>
#       <th id="T_b1a81_level0_col24" class="col_heading level0 col24" >pride</th>
#       <th id="T_b1a81_level0_col25" class="col_heading level0 col25" >realization</th>
#       <th id="T_b1a81_level0_col26" class="col_heading level0 col26" >relief</th>
#       <th id="T_b1a81_level0_col27" class="col_heading level0 col27" >remorse</th>
#       <th id="T_b1a81_level0_col28" class="col_heading level0 col28" >sadness</th>
#       <th id="T_b1a81_level0_col29" class="col_heading level0 col29" >surprise</th>
#       <th id="T_b1a81_level0_col30" class="col_heading level0 col30" >neutral</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1a81_level0_row0" class="row_heading level0 row0" >4480</th>
#       <td id="T_b1a81_row0_col0" class="data row0 col0" >That’s awesome! I’ve seen this video tons of times! It’s one of my favs</td>
#       <td id="T_b1a81_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_b1a81_row0_col2" class="data row0 col2" >eeejyx4</td>
#       <td id="T_b1a81_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_b1a81_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b1a81_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_b1a81_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_b1a81_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_b1a81_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_b1a81_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_b1a81_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_b1a81_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_b1a81_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_b1a81_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_b1a81_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_b1a81_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_b1a81_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_b1a81_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_b1a81_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_b1a81_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_b1a81_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_b1a81_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_b1a81_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_b1a81_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_b1a81_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_b1a81_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_b1a81_row0_col26" class="data row0 col26" >0</td>
#       <td id="T_b1a81_row0_col27" class="data row0 col27" >0</td>
#       <td id="T_b1a81_row0_col28" class="data row0

# %%
print("go_emotions_val info:\n")
print(go_emotions_val.info())
# Out:
# go_emotions_val info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5426 entries, 0 to 5425
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   text            5426 non-null   object
#  1   emotion_labels  5426 non-null   object
#  2   id              5426 non-null   object
#  3   admiration      5426 non-null   int64
#  4   amusement       5426 non-null   int64
#  5   anger           5426 non-null   int64
#  6   annoyance       5426 non-null   int64
#  7   approval        5426 non-null   int64
#  8   caring          5426 non-null   int64
#  9   confusion       5426 non-null   int64
#  10  curiosity       5426 non-null   int64
#  11  desire          5426 non-null   int64
#  12  disappointment  5426 non-null   int64
#  13  disapproval     5426 non-null   int64
#  14  disgust         5426 non-null   int64
#  15  embarrassment   5426 non-null   int64
#  16  excitement      5426 non-null   int64
#  17  fear            5426 non-null   int64
#  18  gratitude       5426 non-null   int64
#  19  grief           5426 non-null   int64
#  20  joy             5426 non-null   int64
#  21  love            5426 non-null   int64
#  22  nervousness     5426 non-null   int64
#  23  optimism        5426 non-null   int64
#  24  pride           5426 non-null   int64
#  25  realization     5426 non-null   int64
#  26  relief          5426 non-null   int64
#  27  remorse         5426 non-null   int64
#  28  sadness         5426 non-null   int64
#  29  surprise        5426 non-null   int64
#  30  neutral         5426 non-null   int64
# dtypes: int64(28), object(3)
# memory usage: 1.3+ MB
# None

# %%
ekman_category_breakdown(go_emotions_val, emotion_names, ekman_map)
# Out:
# Ekman category percentage breakdown:
# anger     : 13.21%
# disgust   : 1.79%
# fear      : 1.94%
# joy       : 40.90%
# sadness   : 7.19%
# surprise  : 11.50%

# %%
text_length_stats(go_emotions_val, text_col="text", by="char")
# Out:
# Text length statistics (characters)
# ====================================
# count     :       5426
# min       :          5
# Q1        :      37.00
# median    :      64.00
# mean      :      68.24
# Q3        :      96.00
# max       :        187
# mode      :         37
# std dev   :      36.91
# variance  :    1362.24
# IQR       :      59.00

# %% [markdown]
# # Exploring Test Set

# %%
print("5 random rows of the test set:\n")
display(go_emotions_test.sample(5).style.set_properties(**{'white-space': 'pre-wrap'}))
# Out:
row4_col5, #T_91593_row4_col6, #T_91593_row4_col7, #T_91593_row4_col8, #T_91593_row4_col9, #T_91593_row4_col10, #T_91593_row4_col11, #T_91593_row4_col12, #T_91593_row4_col13, #T_91593_row4_col14, #T_91593_row4_col15, #T_91593_row4_col16, #T_91593_row4_col17, #T_91593_row4_col18, #T_91593_row4_col19, #T_91593_row4_col20, #T_91593_row4_col21, #T_91593_row4_col22, #T_91593_row4_col23, #T_91593_row4_col24, #T_91593_row4_col25, #T_91593_row4_col26, #T_91593_row4_col27, #T_91593_row4_col28, #T_91593_row4_col29, #T_91593_row4_col30 {
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_91593">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91593_level0_col0" class="col_heading level0 col0" >text</th>
#       <th id="T_91593_level0_col1" class="col_heading level0 col1" >emotion_labels</th>
#       <th id="T_91593_level0_col2" class="col_heading level0 col2" >id</th>
#       <th id="T_91593_level0_col3" class="col_heading level0 col3" >admiration</th>
#       <th id="T_91593_level0_col4" class="col_heading level0 col4" >amusement</th>
#       <th id="T_91593_level0_col5" class="col_heading level0 col5" >anger</th>
#       <th id="T_91593_level0_col6" class="col_heading level0 col6" >annoyance</th>
#       <th id="T_91593_level0_col7" class="col_heading level0 col7" >approval</th>
#       <th id="T_91593_level0_col8" class="col_heading level0 col8" >caring</th>
#       <th id="T_91593_level0_col9" class="col_heading level0 col9" >confusion</th>
#       <th id="T_91593_level0_col10" class="col_heading level0 col10" >curiosity</th>
#       <th id="T_91593_level0_col11" class="col_heading level0 col11" >desire</th>
#       <th id="T_91593_level0_col12" class="col_heading level0 col12" >disappointment</th>
#       <th id="T_91593_level0_col13" class="col_heading level0 col13" >disapproval</th>
#       <th id="T_91593_level0_col14" class="col_heading level0 col14" >disgust</th>
#       <th id="T_91593_level0_col15" class="col_heading level0 col15" >embarrassment</th>
#       <th id="T_91593_level0_col16" class="col_heading level0 col16" >excitement</th>
#       <th id="T_91593_level0_col17" class="col_heading level0 col17" >fear</th>
#       <th id="T_91593_level0_col18" class="col_heading level0 col18" >gratitude</th>
#       <th id="T_91593_level0_col19" class="col_heading level0 col19" >grief</th>
#       <th id="T_91593_level0_col20" class="col_heading level0 col20" >joy</th>
#       <th id="T_91593_level0_col21" class="col_heading level0 col21" >love</th>
#       <th id="T_91593_level0_col22" class="col_heading level0 col22" >nervousness</th>
#       <th id="T_91593_level0_col23" class="col_heading level0 col23" >optimism</th>
#       <th id="T_91593_level0_col24" class="col_heading level0 col24" >pride</th>
#       <th id="T_91593_level0_col25" class="col_heading level0 col25" >realization</th>
#       <th id="T_91593_level0_col26" class="col_heading level0 col26" >relief</th>
#       <th id="T_91593_level0_col27" class="col_heading level0 col27" >remorse</th>
#       <th id="T_91593_level0_col28" class="col_heading level0 col28" >sadness</th>
#       <th id="T_91593_level0_col29" class="col_heading level0 col29" >surprise</th>
#       <th id="T_91593_level0_col30" class="col_heading level0 col30" >neutral</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91593_level0_row0" class="row_heading level0 row0" >2605</th>
#       <td id="T_91593_row0_col0" class="data row0 col0" >I had forgotten it was coming up until I saw this. That us my level of excitement and anticipation.</td>
#       <td id="T_91593_row0_col1" class="data row0 col1" >22</td>
#       <td id="T_91593_row0_col2" class="data row0 col2" >eepwvdp</td>
#       <td id="T_91593_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_91593_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_91593_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_91593_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_91593_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_91593_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_91593_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_91593_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_91593_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_91593_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_91593_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_91593_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_91593_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_91593_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_91593_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_91593_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_91593_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_91593_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_91593_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_91593_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_91593_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_91593_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_91593_row0_col25" class="data row0 col25" >1</td>
#       <td id="T_91593_row0_col26" class="data row0 col26" >0</td>
#       <td id="T_91593_row0_col27" class="data row0 col27" >0</td>
#       <td id="T_91593_

# %%
print("go_emotions_test info:\n")
print(go_emotions_test.info())
# Out:
# go_emotions_test info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5427 entries, 0 to 5426
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   text            5427 non-null   object
#  1   emotion_labels  5427 non-null   object
#  2   id              5427 non-null   object
#  3   admiration      5427 non-null   int64
#  4   amusement       5427 non-null   int64
#  5   anger           5427 non-null   int64
#  6   annoyance       5427 non-null   int64
#  7   approval        5427 non-null   int64
#  8   caring          5427 non-null   int64
#  9   confusion       5427 non-null   int64
#  10  curiosity       5427 non-null   int64
#  11  desire          5427 non-null   int64
#  12  disappointment  5427 non-null   int64
#  13  disapproval     5427 non-null   int64
#  14  disgust         5427 non-null   int64
#  15  embarrassment   5427 non-null   int64
#  16  excitement      5427 non-null   int64
#  17  fear            5427 non-null   int64
#  18  gratitude       5427 non-null   int64
#  19  grief           5427 non-null   int64
#  20  joy             5427 non-null   int64
#  21  love            5427 non-null   int64
#  22  nervousness     5427 non-null   int64
#  23  optimism        5427 non-null   int64
#  24  pride           5427 non-null   int64
#  25  realization     5427 non-null   int64
#  26  relief          5427 non-null   int64
#  27  remorse         5427 non-null   int64
#  28  sadness         5427 non-null   int64
#  29  surprise        5427 non-null   int64
#  30  neutral         5427 non-null   int64
# dtypes: int64(28), object(3)
# memory usage: 1.3+ MB
# None

# %%
ekman_category_breakdown(go_emotions_test, emotion_names, ekman_map)
# Out:
# Ekman category percentage breakdown:
# anger     : 13.38%
# disgust   : 2.27%
# fear      : 1.81%
# joy       : 38.77%
# sadness   : 6.98%
# surprise  : 12.47%

# %%
text_length_stats(go_emotions_test, text_col="text", by="char")
# Out:
# Text length statistics (characters)
# ====================================
# count     :       5427
# min       :          5
# Q1        :      37.00
# median    :      65.00
# mean      :      67.82
# Q3        :      95.00
# max       :        184
# mode      :         24
# std dev   :      36.32
# variance  :    1319.03
# IQR       :      58.00

# %% [markdown]
# # Prototype CNN

# %%
sample = "UGH srsly my head is POUNDING! got no sleep AGAIN? fUCK this BS :( cant even think. just wanna cry rn 😭"

# %% [markdown]
# ## Tokenization

# %%
import string

# Create a simple character vocabulary (expand as needed)
all_chars = list(string.ascii_lowercase + string.ascii_uppercase + string.digits +
                 string.punctuation + string.whitespace + "😴😭")
char2idx = {c: i for i, c in enumerate(all_chars)}
vocab_size = len(char2idx)

# Tokenize the sample
tokens = [char2idx.get(c, 0) for c in sample]
print(tokens)
# Out:
# [46, 32, 33, 94, 18, 17, 18, 11, 24, 94, 12, 24, 94, 7, 4, 0, 3, 94, 8, 18, 94, 41, 40, 46, 39, 29, 34, 39, 32, 62, 94, 6, 14, 19, 94, 13, 14, 94, 18, 11, 4, 4, 15, 94, 26, 32, 26, 34, 39, 82, 94, 5, 46, 28, 36, 94, 19, 7, 8, 18, 94, 27, 44, 94, 77, 69, 94, 2, 0, 13, 19, 94, 4, 21, 4, 13, 94, 19, 7, 8, 13, 10, 75, 94, 9, 20, 18, 19, 94, 22, 0, 13, 13, 0, 94, 2, 17, 24, 94, 17, 13, 94, 101]

# %% [markdown]
# ## 16d character vectors

# %%
import torch
import torch.nn as nn

# 16d character embeddings
embedding_dim = 16
embeddings = nn.Embedding(vocab_size, embedding_dim)

char_tensor = torch.tensor(tokens).unsqueeze(0)  # shape: (1, seq_len)
char_embedded = embeddings(char_tensor)          # shape: (1, seq_len, 16)
print(char_embedded.shape)
print(char_embedded[0])  # Print the embeddings for each character
# Out:
# torch.Size([1, 103, 16])
# tensor([[-0.6855,  0.2374,  0.9423,  ..., -0.2039, -0.6758, -0.2522],
#         [-0.5229,  0.1004,  0.7161,  ...,  0.4647,  0.1572,  1.1195],
#         [ 3.1409, -1.0289, -1.0088,  ...,  0.7705, -0.0569, -0.9204],
#         ...,
#         [-0.7632, -0.2485, -0.4542,  ...,  1.0456,  0.9348,  0.1926],
#         [-0.0487,  0.6263, -0.7100,  ...,  0.0807,  0.4327,  0.1125],
#         [ 0.2765,  0.0762, -1.5887,  ..., -1.2972, -0.6271,  0.1156]],
#        grad_fn=<SelectBackward0>)

# %% [markdown]
# ## trigrams

# %%
conv3 = nn.Conv1d(in_channels=embedding_dim, out_channels=21, kernel_size=3, padding=1)
x3 = char_embedded.permute(0, 2, 1)  # (batch, channels, seq_len)
trigrams = conv3(x3)                 # shape: (1, 21, seq_len)
print(trigrams.shape)
print(trigrams[0].permute(1, 0))     # (seq_len, 21)
# Out:
# torch.Size([1, 21, 103])
# tensor([[ 0.2084,  0.3597,  0.2274,  ..., -0.5563, -0.3191, -0.2590],
#         [ 0.0020, -0.2692, -0.3644,  ..., -0.0143, -0.4366,  0.0640],
#         [-1.2734,  0.0370, -0.0141,  ...,  0.4082, -0.6955, -0.6873],
#         ...,
#         [-0.7055,  0.5607, -0.3426,  ...,  0.3591, -0.5932, -0.2107],
#         [ 0.2101, -0.0376,  0.3486,  ..., -0.2600, -0.3475,  0.3847],
#         [-0.1261, -0.6108,  0.3807,  ...,  0.1977,  0.3555, -0.2364]],
#        grad_fn=<PermuteBackward0>)

# %% [markdown]
# ## pentagrams

# %%
conv5 = nn.Conv1d(in_channels=embedding_dim, out_channels=21, kernel_size=5, padding=2)
pentagrams = conv5(x3)               # shape: (1, 21, seq_len)
print(pentagrams.shape)
print(pentagrams[0].permute(1, 0))   # (seq_len, 21)
# Out:
# torch.Size([1, 21, 103])
# tensor([[-0.5677,  0.5270, -0.6463,  ..., -0.4880, -0.3243, -0.7473],
#         [ 0.1111,  0.0311, -0.2414,  ...,  0.4528, -0.3548, -0.2211],
#         [ 0.1570,  0.1346,  1.2926,  ...,  0.8355, -0.2446,  1.0025],
#         ...,
#         [-0.4010, -0.2806,  0.4558,  ..., -0.1156, -0.8366,  0.4565],
#         [ 0.5431,  0.0023, -0.2087,  ...,  0.8587,  0.0194, -0.3657],
#         [ 0.2830, -0.0856,  0.0829,  ...,  0.4055, -0.0624,  0.0200]],
#        grad_fn=<PermuteBackward0>)

# %% [markdown]
# ## Heptagrams

# %%
conv7 = nn.Conv1d(in_channels=embedding_dim, out_channels=22, kernel_size=7, padding=3)
heptagrams = conv7(x3)               # shape: (1, 22, seq_len)
print(heptagrams.shape)
print(heptagrams[0].permute(1, 0))   # (seq_len, 22)
# Out:
# torch.Size([1, 22, 103])
# tensor([[ 0.0172,  0.5431,  0.2691,  ...,  0.0035,  0.2570, -0.1028],
#         [-0.4761,  0.9771,  0.3356,  ...,  0.3602,  0.6150, -0.2833],
#         [ 0.2223, -0.8046,  0.5188,  ...,  0.7435, -0.0702,  0.4360],
#         ...,
#         [ 0.2749,  0.7478, -0.3363,  ...,  0.5630,  0.1114,  0.7478],
#         [ 0.4363,  0.7342,  0.3361,  ...,  0.5656,  0.6235,  0.1316],
#         [ 0.6062,  0.1161,  0.3271,  ...,  0.3125,  0.0785,  0.9761]],
#        grad_fn=<PermuteBackward0>)

# %% [markdown]
# ## max pooling

# %%
# For each set of filters, take the max across the time dimension (seq_len)
trigram_pooled = torch.max(trigrams, dim=2).values  # (1, 21)
pentagram_pooled = torch.max(pentagrams, dim=2).values  # (1, 21)
heptagram_pooled = torch.max(heptagrams, dim=2).values  # (1, 22)

print(trigram_pooled)
print(pentagram_pooled)
print(heptagram_pooled)
# Out:
# tensor([[0.9900, 1.3106, 1.2958, 0.7615, 0.9688, 1.3246, 1.6915, 0.8765, 1.3719,
#          1.8127, 1.3986, 1.0496, 1.7072, 1.2561, 1.3346, 1.5232, 1.5482, 1.5766,
#          1.1086, 0.9154, 1.1420]], grad_fn=<MaxBackward0>)
# tensor([[1.4481, 0.9588, 1.5172, 1.5790, 1.9479, 1.3800, 1.4626, 1.7500, 1.8412,
#          0.9124, 0.9819, 1.4804, 1.2877, 1.1337, 1.8784, 1.5366, 2.2297, 1.4264,
#          1.1220, 1.9034, 1.5342]], grad_fn=<MaxBackward0>)
# tensor([[1.6251, 1.5898, 1.4043, 1.7200, 1.3100, 1.3342, 1.6767, 1.1499, 1.5224,
#          1.7667, 1.4944, 1.8362, 1.7404, 1.0477, 1.6774, 1.4591, 1.6216, 1.0723,
#          1.1671, 1.5731, 1.4605, 1.8475]], grad_fn=<MaxBackward0>)

# %% [markdown]
# ## 64d output

# %%
final_cnn_output = torch.cat([trigram_pooled, pentagram_pooled, heptagram_pooled], dim=1)  # (1, 64)
print(final_cnn_output.shape)
print(final_cnn_output)
# Out:
# torch.Size([1, 64])
# tensor([[0.9900, 1.3106, 1.2958, 0.7615, 0.9688, 1.3246, 1.6915, 0.8765, 1.3719,
#          1.8127, 1.3986, 1.0496, 1.7072, 1.2561, 1.3346, 1.5232, 1.5482, 1.5766,
#          1.1086, 0.9154, 1.1420, 1.4481, 0.9588, 1.5172, 1.5790, 1.9479, 1.3800,
#          1.4626, 1.7500, 1.8412, 0.9124, 0.9819, 1.4804, 1.2877, 1.1337, 1.8784,
#          1.5366, 2.2297, 1.4264, 1.1220, 1.9034, 1.5342, 1.6251, 1.5898, 1.4043,
#          1.7200, 1.3100, 1.3342, 1.6767, 1.1499, 1.5224, 1.7667, 1.4944, 1.8362,
#          1.7404, 1.0477, 1.6774, 1.4591, 1.6216, 1.0723, 1.1671, 1.5731, 1.4605,
#          1.8475]], grad_fn=<CatBackward0>)
