# %% [markdown]
# Emotion Classifier

# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 200)

import json
from typing import List, Dict, Union

# %% [markdown]
# ## Reading in the Data

# %%
# Load emotion names from file
with open('../datasets/GoEmotions/emotions.txt', 'r') as f:
    emotion_names = [line.strip() for line in f]

# Function to read and expand one file
def load_go_emotions_split(path):
    df = pd.read_csv(path, sep='\t', header=None, names=['text', 'emotion_labels', 'id'])
    # Create 28 one-hot columns, all default to 0
    for i, emo in enumerate(emotion_names):
        df[emo] = 0
    # Fill columns by parsing emotion_labels
    for idx, row in df.iterrows():
        label_idxs = list(map(int, row['emotion_labels'].split(',')))
        for label in label_idxs:
            df.at[idx, emotion_names[label]] = 1
    return df

# Load all splits
go_emotions_train = load_go_emotions_split('../datasets/GoEmotions/train.tsv')
go_emotions_val   = load_go_emotions_split('../datasets/GoEmotions/dev.tsv')
go_emotions_test  = load_go_emotions_split('../datasets/GoEmotions/test.tsv')

# Read in the Ekman mapping
with open('../datasets/GoEmotions/ekman_mapping.json', 'r') as f:
    ekman_map = json.load(f)

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# ### Ekman Mapping

# %%
def ekman_category_breakdown(
    df: pd.DataFrame,
    emotion_columns: list,
    ekman_mapping: dict
) -> None:
    """
    Prints a clean percentage breakdown of each Ekman umbrella category in the dataset.

    Args:
        df (pd.DataFrame): DataFrame with one-hot columns for emotions.
        emotion_columns (list): List of the 28 emotion column names.
        ekman_mapping (dict): Dict mapping Ekman categories to emotion names.
    """
    total = len(df)
    print("Ekman category percentage breakdown:")
    for ekman_cat, fine_emotions in ekman_mapping.items():
        present = df[fine_emotions].any(axis=1)
        pct = present.sum() / total * 100
        print(f"{ekman_cat:<9} : {pct:.2f}%")

# %% [markdown]
# ### Text Stats

# %%
def text_length_stats(
    df: pd.DataFrame,
    text_col: str = "text",
    by: str = "char",
    return_df: bool = False
):
    """
    Print a neatly aligned stats table for lengths of the text column (char or word count).

    Args:
        df (pd.DataFrame): DataFrame with the text data.
        text_col (str): Column name containing text. Default 'text'.
        by (str): 'char' for character count, 'word' for word count.
        return_df (bool): If True, also return the stats as a DataFrame.

    Returns:
        Optional[pd.DataFrame]: Stats DataFrame if requested.
    """
    if by == "char":
        lengths = df[text_col].astype(str).apply(len)
    elif by == "word":
        lengths = df[text_col].astype(str).apply(lambda x: len(x.split()))
    else:
        raise ValueError("`by` must be 'char' or 'word'")

    stats = [
        ("count",        lengths.count()),
        ("min",          lengths.min()),
        ("Q1",           lengths.quantile(0.25)),
        ("median",       lengths.median()),
        ("mean",         lengths.mean()),
        ("Q3",           lengths.quantile(0.75)),
        ("max",          lengths.max()),
        ("mode",         lengths.mode().values[0] if not lengths.mode().empty else None),
        ("std dev",      lengths.std()),
        ("variance",     lengths.var()),
        ("IQR",          lengths.quantile(0.75) - lengths.quantile(0.25)),
    ]
    print(f"\n{'Text length statistics (' + ('characters' if by=='char' else 'words') + ')':^36}")
    print("=" * 36)
    for label, val in stats:
        print(f"{label:<10}: {val:>10.2f}" if isinstance(val, float) else f"{label:<10}: {val:>10}")
    if return_df:
        return pd.DataFrame(stats, columns=["statistic", "value"]).set_index("statistic")

# %% [markdown]
# # Exploring Training Set

# %%
print("5 random rows of the training set:\n")
display(go_emotions_train.sample(5).style.set_properties(**{'white-space': 'pre-wrap'}))
# Out:
# 5 random rows of the training set:
# <style type="text/css">
# #T_2dc2a_row0_col0, #T_2dc2a_row0_col1, #T_2dc2a_row0_col2, #T_2dc2a_row0_col3, #T_2dc2a_row0_col4, #T_2dc2a_row0_col5, #T_2dc2a_row0_col6, #T_2dc2a_row0_col7, #T_2dc2a_row0_col8, #T_2dc2a_row0_col9, #T_2dc2a_row0_col10, #T_2dc2a_row0_col11, #T_2dc2a_row0_col12, #T_2dc2a_row0_col13, #T_2dc2a_row0_col14, #T_2dc2a_row0_col15, #T_2dc2a_row0_col16, #T_2dc2a_row0_col17, #T_2dc2a_row0_col18, #T_2dc2a_row0_col19, #T_2dc2a_row0_col20, #T_2dc2a_row0_col21, #T_2dc2a_row0_col22, #T_2dc2a_row0_col23, #T_2dc2a_row0_col24, #T_2dc2a_row0_col25, #T_2dc2a_row0_col26, #T_2dc2a_row0_col27, #T_2dc2a_row0_col28, #T_2dc2a_row0_col29, #T_2dc2a_row0_col30, #T_2dc2a_row1_col0, #T_2dc2a_row1_col1, #T_2dc2a_row1_col2, #T_2dc2a_row1_col3, #T_2dc2a_row1_col4, #T_2dc2a_row1_col5, #T_2dc2a_row1_col6, #T_2dc2a_row1_col7, #T_2dc2a_row1_col8, #T_2dc2a_row1_col9, #T_2dc2a_row1_col10, #T_2dc2a_row1_col11, #T_2dc2a_row1_col12, #T_2dc2a_row1_col13, #T_2dc2a_row1_col14, #T_2dc2a_row1_col15, #T_2dc2a_row1_col16, #T_2dc2a_row1_col17, #T_2dc2a_row1_col18, #T_2dc2a_row1_col19, #T_2dc2a_row1_col20, #T_2dc2a_row1_col21, #T_2dc2a_row1_col22, #T_2dc2a_row1_col23, #T_2dc2a_row1_col24, #T_2dc2a_row1_col25, #T_2dc2a_row1_col26, #T_2dc2a_row1_col27, #T_2dc2a_row1_col28, #T_2dc2a_row1_col29, #T_2dc2a_row1_col30, #T_2dc2a_row2_col0, #T_2dc2a_row2_col1, #T_2dc2a_row2_col2, #T_2dc2a_row2_col3, #T_2dc2a_row2_col4, #T_2dc2a_row2_col5, #T_2dc2a_row2_col6, #T_2dc2a_row2_col7, #T_2dc2a_row2_col8, #T_2dc2a_row2_col9, #T_2dc2a_row2_col10, #T_2dc2a_row2_col11, #T_2dc2a_row2_col12, #T_2dc2a_row2_col13, #T_2dc2a_row2_col14, #T_2dc2a_row2_col15, #T_2dc2a_row2_col16, #T_2dc2a_row2_col17, #T_2dc2a_row2_col18, #T_2dc2a_row2_col19, #T_2dc2a_row2_col20, #T_2dc2a_row2_col21, #T_2dc2a_row2_col22, #T_2dc2a_row2_col23, #T_2dc2a_row2_col24, #T_2dc2a_row2_col25, #T_2dc2a_row2_col26, #T_2dc2a_row2_col27, #T_2dc2a_row2_col28, #T_2dc2a_row2_col29, #T_2dc2a_row2_col30, #T_2dc2a_row3_col0, #T_2dc2a_row3_col1, #T_2dc2a_row3_col2, #T_2dc2a_row3_col3, #T_2dc2a_row3_col4, #T_2dc2a_row3_col5, #T_2dc2a_row3_col6, #T_2dc2a_row3_col7, #T_2dc2a_row3_col8, #T_2dc2a_row3_col9, #T_2dc2a_row3_col10, #T_2dc2a_row3_col11, #T_2dc2a_row3_col12, #T_2dc2a_row3_col13, #T_2dc2a_row3_col14, #T_2dc2a_row3_col15, #T_2dc2a_row3_col16, #T_2dc2a_row3_col17, #T_2dc2a_row3_col18, #T_2dc2a_row3_col19, #T_2dc2a_row3_col20, #T_2dc2a_row3_col21, #T_2dc2a_row3_col22, #T_2dc2a_row3_col23, #T_2dc2a_row3_col24, #T_2dc2a_row3_col25, #T_2dc2a_row3_col26, #T_2dc2a_row3_col27, #T_2dc2a_row3_col28, #T_2dc2a_row3_col29, #T_2dc2a_row3_col30, #T_2dc2a_row4_col0, #T_2dc2a_row4_col1, #T_2dc2a_row4_col2, #T_2dc2a_row4_col3, #T_2dc2a_row4_col4, #T_2dc2a_row4_col5, #T_2dc2a_row4_col6, #T_2dc2a_row4_col7, #T_2dc2a_row4_col8, #T_2dc2a_row4_col9, #T_2dc2a_row4_col10, #T_2dc2a_row4_col11, #T_2dc2a_row4_col12, #T_2dc2a_row4_col13, #T_2dc2a_row4_col14, #T_2dc2a_row4_col15, #T_2dc2a_row4_col16, #T_2dc2a_row4_col17, #T_2dc2a_row4_col18, #T_2dc2a_row4_col19, #T_2dc2a_row4_col20, #T_2dc2a_row4_col21, #T_2dc2a_row4_col22, #T_2dc2a_row4_col23, #T_2dc2a_row4_col24, #T_2dc2a_row4_col25, #T_2dc2a_row4_col26, #T_2dc2a_row4_col27, #T_2dc2a_row4_col28, #T_2dc2a_row4_col29, #T_2dc2a_row4_col30 {
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_2dc2a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2dc2a_level0_col0" class="col_heading level0 col0" >text</th>
#       <th id="T_2dc2a_level0_col1" class="col_heading level0 col1" >emotion_labels</th>
#       <th id="T_2dc2a_level0_col2" class="col_heading level0 col2" >id</th>
#       <th id="T_2dc2a_level0_col3" class="col_heading level0 col3" >admiration</th>
#       <th id="T_2dc2a_level0_col4" class="col_heading level0 col4" >amusement</th>
#       <th id="T_2dc2a_level0_col5" class="col_heading level0 col5" >anger</th>
#       <th id="T_2dc2a_level0_col6" class="col_heading level0 col6" >annoyance</th>
#       <th id="T_2dc2a_level0_col7" class="col_heading level0 col7" >approval</th>
#       <th id="T_2dc2a_level0_col8" class="col_heading level0 col8" >caring</th>
#       <th id="T_2dc2a_level0_col9" class="col_heading level0 col9" >confusion</th>
#       <th id="T_2dc2a_level0_col10" class="col_heading level0 col10" >curiosity</th>
#       <th id="T_2dc2a_level0_col11" class="col_heading level0 col11" >desire</th>
#       <th id="T_2dc2a_level0_col12" class="col_heading level0 col12" >disappointment</th>
#       <th id="T_2dc2a_level0_col13" class="col_heading level0 col13" >disapproval</th>
#       <th id="T_2dc2a_level0_col14" class="col_heading level0 col14" >disgust</th>
#       <th id="T_2dc2a_level0_col15" class="col_heading level0 col15" >embarrassment</th>
#       <th id="T_2dc2a_level0_col16" class="col_heading level0 col16" >excitement</th>
#       <th id="T_2dc2a_level0_col17" class="col_heading level0 col17" >fear</th>
#       <th id="T_2dc2a_level0_col18" class="col_heading level0 col18" >gratitude</th>
#       <th id="T_2dc2a_level0_col19" class="col_heading level0 col19" >grief</th>
#       <th id="T_2dc2a_level0_col20" class="col_heading level0 col20" >joy</th>
#       <th id="T_2dc2a_level0_col21" class="col_heading level0 col21" >love</th>
#       <th id="T_2dc2a_level0_col22" class="col_heading level0 col22" >nervousness</th>
#       <th id="T_2dc2a_level0_col23" class="col_heading level0 col23" >optimism</th>
#       <th id="T_2dc2a_level0_col24" class="col_heading level0 col24" >pride</th>
#       <th id="T_2dc2a_level0_col25" class="col_heading level0 col25" >realization</th>
#       <th id="T_2dc2a_level0_col26" class="col_heading level0 col26" >relief</th>
#       <th id="T_2dc2a_level0_col27" class="col_heading level0 col27" >remorse</th>
#       <th id="T_2dc2a_level0_col28" class="col_heading level0 col28" >sadness</th>
#       <th id="T_2dc2a_level0_col29" class="col_heading level0 col29" >surprise</th>
#       <th id="T_2dc2a_level0_col30" class="col_heading level0 col30" >neutral</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2dc2a_level0_row0" class="row_heading level0 row0" >42050</th>
#       <td id="T_2dc2a_row0_col0" class="data row0 col0" >I don’t get why he hasn’t brought his insta account back, he did used to use it from time to time</td>
#       <td id="T_2dc2a_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_2dc2a_row0_col2" class="data row0 col2" >eduux4x</td>
#       <td id="T_2dc2a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_2dc2a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_2dc2a_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_2dc2a_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_2dc2a_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_2dc2a_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_2dc2a_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_2dc2a_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_2dc2a_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_2dc2a_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_2dc2a_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_2dc2a_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_2dc2a_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_2dc2a_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_2dc2a_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_2dc2a_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_2dc2a_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_2dc2a_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_2dc2a_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_2dc2a_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_2dc2a_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_2dc2a_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_2dc2a_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_2dc2a_row0_col26" class="data row0 col26" >0</td>
#       <td id="T_2dc2a_row0_col27" class="data row0 col27" >0</td>
#       <td id="T_2dc2a_ro

# %%
print("go_emotion_train info:\n")
print(go_emotions_train.info())
# Out:
# go_emotion_train info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43410 entries, 0 to 43409
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   text            43410 non-null  object
#  1   emotion_labels  43410 non-null  object
#  2   id              43410 non-null  object
#  3   admiration      43410 non-null  int64
#  4   amusement       43410 non-null  int64
#  5   anger           43410 non-null  int64
#  6   annoyance       43410 non-null  int64
#  7   approval        43410 non-null  int64
#  8   caring          43410 non-null  int64
#  9   confusion       43410 non-null  int64
#  10  curiosity       43410 non-null  int64
#  11  desire          43410 non-null  int64
#  12  disappointment  43410 non-null  int64
#  13  disapproval     43410 non-null  int64
#  14  disgust         43410 non-null  int64
#  15  embarrassment   43410 non-null  int64
#  16  excitement      43410 non-null  int64
#  17  fear            43410 non-null  int64
#  18  gratitude       43410 non-null  int64
#  19  grief           43410 non-null  int64
#  20  joy             43410 non-null  int64
#  21  love            43410 non-null  int64
#  22  nervousness     43410 non-null  int64
#  23  optimism        43410 non-null  int64
#  24  pride           43410 non-null  int64
#  25  realization     43410 non-null  int64
#  26  relief          43410 non-null  int64
#  27  remorse         43410 non-null  int64
#  28  sadness         43410 non-null  int64
#  29  surprise        43410 non-null  int64
#  30  neutral         43410 non-null  int64
# dtypes: int64(28), object(3)
# memory usage: 10.3+ MB
# None

# %%
ekman_category_breakdown(go_emotions_train, emotion_names, ekman_map)
# Out:
# Ekman category percentage breakdown:
# anger     : 12.85%
# disgust   : 1.83%
# fear      : 1.67%
# joy       : 40.11%
# sadness   : 7.52%
# surprise  : 12.36%

# %%
text_length_stats(go_emotions_train, text_col="text", by="char")
# Out:
# Text length statistics (characters)
# ====================================
# count     :      43410
# min       :          2
# Q1        :      38.00
# median    :      65.00
# mean      :      68.40
# Q3        :      96.00
# max       :        703
# mode      :         56
# std dev   :      36.72
# variance  :    1348.50
# IQR       :      58.00

# %% [markdown]
# # Exploring Validation Set

# %%
print("5 random rows of the validation set:\n")
display(go_emotions_val.sample(5).style.set_properties(**{'white-space': 'pre-wrap'}))
# Out:
# 5 random rows of the validation set:
# <style type="text/css">
# #T_54777_row0_col0, #T_54777_row0_col1, #T_54777_row0_col2, #T_54777_row0_col3, #T_54777_row0_col4, #T_54777_row0_col5, #T_54777_row0_col6, #T_54777_row0_col7, #T_54777_row0_col8, #T_54777_row0_col9, #T_54777_row0_col10, #T_54777_row0_col11, #T_54777_row0_col12, #T_54777_row0_col13, #T_54777_row0_col14, #T_54777_row0_col15, #T_54777_row0_col16, #T_54777_row0_col17, #T_54777_row0_col18, #T_54777_row0_col19, #T_54777_row0_col20, #T_54777_row0_col21, #T_54777_row0_col22, #T_54777_row0_col23, #T_54777_row0_col24, #T_54777_row0_col25, #T_54777_row0_col26, #T_54777_row0_col27, #T_54777_row0_col28, #T_54777_row0_col29, #T_54777_row0_col30, #T_54777_row1_col0, #T_54777_row1_col1, #T_54777_row1_col2, #T_54777_row1_col3, #T_54777_row1_col4, #T_54777_row1_col5, #T_54777_row1_col6, #T_54777_row1_col7, #T_54777_row1_col8, #T_54777_row1_col9, #T_54777_row1_col10, #T_54777_row1_col11, #T_54777_row1_col12, #T_54777_row1_col13, #T_54777_row1_col14, #T_54777_row1_col15, #T_54777_row1_col16, #T_54777_row1_col17, #T_54777_row1_col18, #T_54777_row1_col19, #T_54777_row1_col20, #T_54777_row1_col21, #T_54777_row1_col22, #T_54777_row1_col23, #T_54777_row1_col24, #T_54777_row1_col25, #T_54777_row1_col26, #T_54777_row1_col27, #T_54777_row1_col28, #T_54777_row1_col29, #T_54777_row1_col30, #T_54777_row2_col0, #T_54777_row2_col1, #T_54777_row2_col2, #T_54777_row2_col3, #T_54777_row2_col4, #T_54777_row2_col5, #T_54777_row2_col6, #T_54777_row2_col7, #T_54777_row2_col8, #T_54777_row2_col9, #T_54777_row2_col10, #T_54777_row2_col11, #T_54777_row2_col12, #T_54777_row2_col13, #T_54777_row2_col14, #T_54777_row2_col15, #T_54777_row2_col16, #T_54777_row2_col17, #T_54777_row2_col18, #T_54777_row2_col19, #T_54777_row2_col20, #T_54777_row2_col21, #T_54777_row2_col22, #T_54777_row2_col23, #T_54777_row2_col24, #T_54777_row2_col25, #T_54777_row2_col26, #T_54777_row2_col27, #T_54777_row2_col28, #T_54777_row2_col29, #T_54777_row2_col30, #T_54777_row3_col0, #T_54777_row3_col1, #T_54777_row3_col2, #T_54777_row3_col3, #T_54777_row3_col4, #T_54777_row3_col5, #T_54777_row3_col6, #T_54777_row3_col7, #T_54777_row3_col8, #T_54777_row3_col9, #T_54777_row3_col10, #T_54777_row3_col11, #T_54777_row3_col12, #T_54777_row3_col13, #T_54777_row3_col14, #T_54777_row3_col15, #T_54777_row3_col16, #T_54777_row3_col17, #T_54777_row3_col18, #T_54777_row3_col19, #T_54777_row3_col20, #T_54777_row3_col21, #T_54777_row3_col22, #T_54777_row3_col23, #T_54777_row3_col24, #T_54777_row3_col25, #T_54777_row3_col26, #T_54777_row3_col27, #T_54777_row3_col28, #T_54777_row3_col29, #T_54777_row3_col30, #T_54777_row4_col0, #T_54777_row4_col1, #T_54777_row4_col2, #T_54777_row4_col3, #T_54777_row4_col4, #T_54777_row4_col5, #T_54777_row4_col6, #T_54777_row4_col7, #T_54777_row4_col8, #T_54777_row4_col9, #T_54777_row4_col10, #T_54777_row4_col11, #T_54777_row4_col12, #T_54777_row4_col13, #T_54777_row4_col14, #T_54777_row4_col15, #T_54777_row4_col16, #T_54777_row4_col17, #T_54777_row4_col18, #T_54777_row4_col19, #T_54777_row4_col20, #T_54777_row4_col21, #T_54777_row4_col22, #T_54777_row4_col23, #T_54777_row4_col24, #T_54777_row4_col25, #T_54777_row4_col26, #T_54777_row4_col27, #T_54777_row4_col28, #T_54777_row4_col29, #T_54777_row4_col30 {
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_54777">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54777_level0_col0" class="col_heading level0 col0" >text</th>
#       <th id="T_54777_level0_col1" class="col_heading level0 col1" >emotion_labels</th>
#       <th id="T_54777_level0_col2" class="col_heading level0 col2" >id</th>
#       <th id="T_54777_level0_col3" class="col_heading level0 col3" >admiration</th>
#       <th id="T_54777_level0_col4" class="col_heading level0 col4" >amusement</th>
#       <th id="T_54777_level0_col5" class="col_heading level0 col5" >anger</th>
#       <th id="T_54777_level0_col6" class="col_heading level0 col6" >annoyance</th>
#       <th id="T_54777_level0_col7" class="col_heading level0 col7" >approval</th>
#       <th id="T_54777_level0_col8" class="col_heading level0 col8" >caring</th>
#       <th id="T_54777_level0_col9" class="col_heading level0 col9" >confusion</th>
#       <th id="T_54777_level0_col10" class="col_heading level0 col10" >curiosity</th>
#       <th id="T_54777_level0_col11" class="col_heading level0 col11" >desire</th>
#       <th id="T_54777_level0_col12" class="col_heading level0 col12" >disappointment</th>
#       <th id="T_54777_level0_col13" class="col_heading level0 col13" >disapproval</th>
#       <th id="T_54777_level0_col14" class="col_heading level0 col14" >disgust</th>
#       <th id="T_54777_level0_col15" class="col_heading level0 col15" >embarrassment</th>
#       <th id="T_54777_level0_col16" class="col_heading level0 col16" >excitement</th>
#       <th id="T_54777_level0_col17" class="col_heading level0 col17" >fear</th>
#       <th id="T_54777_level0_col18" class="col_heading level0 col18" >gratitude</th>
#       <th id="T_54777_level0_col19" class="col_heading level0 col19" >grief</th>
#       <th id="T_54777_level0_col20" class="col_heading level0 col20" >joy</th>
#       <th id="T_54777_level0_col21" class="col_heading level0 col21" >love</th>
#       <th id="T_54777_level0_col22" class="col_heading level0 col22" >nervousness</th>
#       <th id="T_54777_level0_col23" class="col_heading level0 col23" >optimism</th>
#       <th id="T_54777_level0_col24" class="col_heading level0 col24" >pride</th>
#       <th id="T_54777_level0_col25" class="col_heading level0 col25" >realization</th>
#       <th id="T_54777_level0_col26" class="col_heading level0 col26" >relief</th>
#       <th id="T_54777_level0_col27" class="col_heading level0 col27" >remorse</th>
#       <th id="T_54777_level0_col28" class="col_heading level0 col28" >sadness</th>
#       <th id="T_54777_level0_col29" class="col_heading level0 col29" >surprise</th>
#       <th id="T_54777_level0_col30" class="col_heading level0 col30" >neutral</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54777_level0_row0" class="row_heading level0 row0" >3469</th>
#       <td id="T_54777_row0_col0" class="data row0 col0" >If this gets put in a video, hi mom!</td>
#       <td id="T_54777_row0_col1" class="data row0 col1" >27</td>
#       <td id="T_54777_row0_col2" class="data row0 col2" >ef8jhlq</td>
#       <td id="T_54777_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_54777_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_54777_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_54777_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_54777_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_54777_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_54777_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_54777_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_54777_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_54777_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_54777_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_54777_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_54777_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_54777_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_54777_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_54777_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_54777_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_54777_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_54777_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_54777_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_54777_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_54777_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_54777_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_54777_row0_col26" class="data row0 col26" >0</td>
#       <td id="T_54777_row0_col27" class="data row0 col27" >0</td>
#       <td id="T_54777_row0_col28" class="data row0 col28" >0</td>
#       <td id="T_547

# %%
print("go_emotions_val info:\n")
print(go_emotions_val.info())
# Out:
# go_emotions_val info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5426 entries, 0 to 5425
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   text            5426 non-null   object
#  1   emotion_labels  5426 non-null   object
#  2   id              5426 non-null   object
#  3   admiration      5426 non-null   int64
#  4   amusement       5426 non-null   int64
#  5   anger           5426 non-null   int64
#  6   annoyance       5426 non-null   int64
#  7   approval        5426 non-null   int64
#  8   caring          5426 non-null   int64
#  9   confusion       5426 non-null   int64
#  10  curiosity       5426 non-null   int64
#  11  desire          5426 non-null   int64
#  12  disappointment  5426 non-null   int64
#  13  disapproval     5426 non-null   int64
#  14  disgust         5426 non-null   int64
#  15  embarrassment   5426 non-null   int64
#  16  excitement      5426 non-null   int64
#  17  fear            5426 non-null   int64
#  18  gratitude       5426 non-null   int64
#  19  grief           5426 non-null   int64
#  20  joy             5426 non-null   int64
#  21  love            5426 non-null   int64
#  22  nervousness     5426 non-null   int64
#  23  optimism        5426 non-null   int64
#  24  pride           5426 non-null   int64
#  25  realization     5426 non-null   int64
#  26  relief          5426 non-null   int64
#  27  remorse         5426 non-null   int64
#  28  sadness         5426 non-null   int64
#  29  surprise        5426 non-null   int64
#  30  neutral         5426 non-null   int64
# dtypes: int64(28), object(3)
# memory usage: 1.3+ MB
# None

# %%
ekman_category_breakdown(go_emotions_val, emotion_names, ekman_map)
# Out:
# Ekman category percentage breakdown:
# anger     : 13.21%
# disgust   : 1.79%
# fear      : 1.94%
# joy       : 40.90%
# sadness   : 7.19%
# surprise  : 11.50%

# %%
text_length_stats(go_emotions_val, text_col="text", by="char")
# Out:
# Text length statistics (characters)
# ====================================
# count     :       5426
# min       :          5
# Q1        :      37.00
# median    :      64.00
# mean      :      68.24
# Q3        :      96.00
# max       :        187
# mode      :         37
# std dev   :      36.91
# variance  :    1362.24
# IQR       :      59.00

# %% [markdown]
# # Exploring Test Set

# %%
print("5 random rows of the test set:\n")
display(go_emotions_test.sample(5).style.set_properties(**{'white-space': 'pre-wrap'}))
# Out:
# 5 random rows of the test set:
# <style type="text/css">
# #T_a6a9e_row0_col0, #T_a6a9e_row0_col1, #T_a6a9e_row0_col2, #T_a6a9e_row0_col3, #T_a6a9e_row0_col4, #T_a6a9e_row0_col5, #T_a6a9e_row0_col6, #T_a6a9e_row0_col7, #T_a6a9e_row0_col8, #T_a6a9e_row0_col9, #T_a6a9e_row0_col10, #T_a6a9e_row0_col11, #T_a6a9e_row0_col12, #T_a6a9e_row0_col13, #T_a6a9e_row0_col14, #T_a6a9e_row0_col15, #T_a6a9e_row0_col16, #T_a6a9e_row0_col17, #T_a6a9e_row0_col18, #T_a6a9e_row0_col19, #T_a6a9e_row0_col20, #T_a6a9e_row0_col21, #T_a6a9e_row0_col22, #T_a6a9e_row0_col23, #T_a6a9e_row0_col24, #T_a6a9e_row0_col25, #T_a6a9e_row0_col26, #T_a6a9e_row0_col27, #T_a6a9e_row0_col28, #T_a6a9e_row0_col29, #T_a6a9e_row0_col30, #T_a6a9e_row1_col0, #T_a6a9e_row1_col1, #T_a6a9e_row1_col2, #T_a6a9e_row1_col3, #T_a6a9e_row1_col4, #T_a6a9e_row1_col5, #T_a6a9e_row1_col6, #T_a6a9e_row1_col7, #T_a6a9e_row1_col8, #T_a6a9e_row1_col9, #T_a6a9e_row1_col10, #T_a6a9e_row1_col11, #T_a6a9e_row1_col12, #T_a6a9e_row1_col13, #T_a6a9e_row1_col14, #T_a6a9e_row1_col15, #T_a6a9e_row1_col16, #T_a6a9e_row1_col17, #T_a6a9e_row1_col18, #T_a6a9e_row1_col19, #T_a6a9e_row1_col20, #T_a6a9e_row1_col21, #T_a6a9e_row1_col22, #T_a6a9e_row1_col23, #T_a6a9e_row1_col24, #T_a6a9e_row1_col25, #T_a6a9e_row1_col26, #T_a6a9e_row1_col27, #T_a6a9e_row1_col28, #T_a6a9e_row1_col29, #T_a6a9e_row1_col30, #T_a6a9e_row2_col0, #T_a6a9e_row2_col1, #T_a6a9e_row2_col2, #T_a6a9e_row2_col3, #T_a6a9e_row2_col4, #T_a6a9e_row2_col5, #T_a6a9e_row2_col6, #T_a6a9e_row2_col7, #T_a6a9e_row2_col8, #T_a6a9e_row2_col9, #T_a6a9e_row2_col10, #T_a6a9e_row2_col11, #T_a6a9e_row2_col12, #T_a6a9e_row2_col13, #T_a6a9e_row2_col14, #T_a6a9e_row2_col15, #T_a6a9e_row2_col16, #T_a6a9e_row2_col17, #T_a6a9e_row2_col18, #T_a6a9e_row2_col19, #T_a6a9e_row2_col20, #T_a6a9e_row2_col21, #T_a6a9e_row2_col22, #T_a6a9e_row2_col23, #T_a6a9e_row2_col24, #T_a6a9e_row2_col25, #T_a6a9e_row2_col26, #T_a6a9e_row2_col27, #T_a6a9e_row2_col28, #T_a6a9e_row2_col29, #T_a6a9e_row2_col30, #T_a6a9e_row3_col0, #T_a6a9e_row3_col1, #T_a6a9e_row3_col2, #T_a6a9e_row3_col3, #T_a6a9e_row3_col4, #T_a6a9e_row3_col5, #T_a6a9e_row3_col6, #T_a6a9e_row3_col7, #T_a6a9e_row3_col8, #T_a6a9e_row3_col9, #T_a6a9e_row3_col10, #T_a6a9e_row3_col11, #T_a6a9e_row3_col12, #T_a6a9e_row3_col13, #T_a6a9e_row3_col14, #T_a6a9e_row3_col15, #T_a6a9e_row3_col16, #T_a6a9e_row3_col17, #T_a6a9e_row3_col18, #T_a6a9e_row3_col19, #T_a6a9e_row3_col20, #T_a6a9e_row3_col21, #T_a6a9e_row3_col22, #T_a6a9e_row3_col23, #T_a6a9e_row3_col24, #T_a6a9e_row3_col25, #T_a6a9e_row3_col26, #T_a6a9e_row3_col27, #T_a6a9e_row3_col28, #T_a6a9e_row3_col29, #T_a6a9e_row3_col30, #T_a6a9e_row4_col0, #T_a6a9e_row4_col1, #T_a6a9e_row4_col2, #T_a6a9e_row4_col3, #T_a6a9e_row4_col4, #T_a6a9e_row4_col5, #T_a6a9e_row4_col6, #T_a6a9e_row4_col7, #T_a6a9e_row4_col8, #T_a6a9e_row4_col9, #T_a6a9e_row4_col10, #T_a6a9e_row4_col11, #T_a6a9e_row4_col12, #T_a6a9e_row4_col13, #T_a6a9e_row4_col14, #T_a6a9e_row4_col15, #T_a6a9e_row4_col16, #T_a6a9e_row4_col17, #T_a6a9e_row4_col18, #T_a6a9e_row4_col19, #T_a6a9e_row4_col20, #T_a6a9e_row4_col21, #T_a6a9e_row4_col22, #T_a6a9e_row4_col23, #T_a6a9e_row4_col24, #T_a6a9e_row4_col25, #T_a6a9e_row4_col26, #T_a6a9e_row4_col27, #T_a6a9e_row4_col28, #T_a6a9e_row4_col29, #T_a6a9e_row4_col30 {
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_a6a9e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6a9e_level0_col0" class="col_heading level0 col0" >text</th>
#       <th id="T_a6a9e_level0_col1" class="col_heading level0 col1" >emotion_labels</th>
#       <th id="T_a6a9e_level0_col2" class="col_heading level0 col2" >id</th>
#       <th id="T_a6a9e_level0_col3" class="col_heading level0 col3" >admiration</th>
#       <th id="T_a6a9e_level0_col4" class="col_heading level0 col4" >amusement</th>
#       <th id="T_a6a9e_level0_col5" class="col_heading level0 col5" >anger</th>
#       <th id="T_a6a9e_level0_col6" class="col_heading level0 col6" >annoyance</th>
#       <th id="T_a6a9e_level0_col7" class="col_heading level0 col7" >approval</th>
#       <th id="T_a6a9e_level0_col8" class="col_heading level0 col8" >caring</th>
#       <th id="T_a6a9e_level0_col9" class="col_heading level0 col9" >confusion</th>
#       <th id="T_a6a9e_level0_col10" class="col_heading level0 col10" >curiosity</th>
#       <th id="T_a6a9e_level0_col11" class="col_heading level0 col11" >desire</th>
#       <th id="T_a6a9e_level0_col12" class="col_heading level0 col12" >disappointment</th>
#       <th id="T_a6a9e_level0_col13" class="col_heading level0 col13" >disapproval</th>
#       <th id="T_a6a9e_level0_col14" class="col_heading level0 col14" >disgust</th>
#       <th id="T_a6a9e_level0_col15" class="col_heading level0 col15" >embarrassment</th>
#       <th id="T_a6a9e_level0_col16" class="col_heading level0 col16" >excitement</th>
#       <th id="T_a6a9e_level0_col17" class="col_heading level0 col17" >fear</th>
#       <th id="T_a6a9e_level0_col18" class="col_heading level0 col18" >gratitude</th>
#       <th id="T_a6a9e_level0_col19" class="col_heading level0 col19" >grief</th>
#       <th id="T_a6a9e_level0_col20" class="col_heading level0 col20" >joy</th>
#       <th id="T_a6a9e_level0_col21" class="col_heading level0 col21" >love</th>
#       <th id="T_a6a9e_level0_col22" class="col_heading level0 col22" >nervousness</th>
#       <th id="T_a6a9e_level0_col23" class="col_heading level0 col23" >optimism</th>
#       <th id="T_a6a9e_level0_col24" class="col_heading level0 col24" >pride</th>
#       <th id="T_a6a9e_level0_col25" class="col_heading level0 col25" >realization</th>
#       <th id="T_a6a9e_level0_col26" class="col_heading level0 col26" >relief</th>
#       <th id="T_a6a9e_level0_col27" class="col_heading level0 col27" >remorse</th>
#       <th id="T_a6a9e_level0_col28" class="col_heading level0 col28" >sadness</th>
#       <th id="T_a6a9e_level0_col29" class="col_heading level0 col29" >surprise</th>
#       <th id="T_a6a9e_level0_col30" class="col_heading level0 col30" >neutral</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6a9e_level0_row0" class="row_heading level0 row0" >3674</th>
#       <td id="T_a6a9e_row0_col0" class="data row0 col0" >thats even scarier haha</td>
#       <td id="T_a6a9e_row0_col1" class="data row0 col1" >1,14</td>
#       <td id="T_a6a9e_row0_col2" class="data row0 col2" >ed9w7gf</td>
#       <td id="T_a6a9e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a6a9e_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_a6a9e_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_a6a9e_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_a6a9e_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_a6a9e_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_a6a9e_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_a6a9e_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_a6a9e_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_a6a9e_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_a6a9e_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_a6a9e_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_a6a9e_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_a6a9e_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_a6a9e_row0_col17" class="data row0 col17" >1</td>
#       <td id="T_a6a9e_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_a6a9e_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_a6a9e_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_a6a9e_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_a6a9e_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_a6a9e_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_a6a9e_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_a6a9e_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_a6a9e_row0_col26" class="data row0 col26" >0</td>
#       <td id="T_a6a9e_row0_col27" class="data row0 col27" >0</td>
#       <td id="T_a6a9e_row0_col28" class="data row0 col28" >0</td>
#       <td id="T_a6a9e_row0_col

# %%
print("go_emotions_test info:\n")
print(go_emotions_test.info())
# Out:
# go_emotions_test info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5427 entries, 0 to 5426
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   text            5427 non-null   object
#  1   emotion_labels  5427 non-null   object
#  2   id              5427 non-null   object
#  3   admiration      5427 non-null   int64
#  4   amusement       5427 non-null   int64
#  5   anger           5427 non-null   int64
#  6   annoyance       5427 non-null   int64
#  7   approval        5427 non-null   int64
#  8   caring          5427 non-null   int64
#  9   confusion       5427 non-null   int64
#  10  curiosity       5427 non-null   int64
#  11  desire          5427 non-null   int64
#  12  disappointment  5427 non-null   int64
#  13  disapproval     5427 non-null   int64
#  14  disgust         5427 non-null   int64
#  15  embarrassment   5427 non-null   int64
#  16  excitement      5427 non-null   int64
#  17  fear            5427 non-null   int64
#  18  gratitude       5427 non-null   int64
#  19  grief           5427 non-null   int64
#  20  joy             5427 non-null   int64
#  21  love            5427 non-null   int64
#  22  nervousness     5427 non-null   int64
#  23  optimism        5427 non-null   int64
#  24  pride           5427 non-null   int64
#  25  realization     5427 non-null   int64
#  26  relief          5427 non-null   int64
#  27  remorse         5427 non-null   int64
#  28  sadness         5427 non-null   int64
#  29  surprise        5427 non-null   int64
#  30  neutral         5427 non-null   int64
# dtypes: int64(28), object(3)
# memory usage: 1.3+ MB
# None

# %%
ekman_category_breakdown(go_emotions_test, emotion_names, ekman_map)
# Out:
# Ekman category percentage breakdown:
# anger     : 13.38%
# disgust   : 2.27%
# fear      : 1.81%
# joy       : 38.77%
# sadness   : 6.98%
# surprise  : 12.47%

# %%
text_length_stats(go_emotions_test, text_col="text", by="char")
# Out:
# Text length statistics (characters)
# ====================================
# count     :       5427
# min       :          5
# Q1        :      37.00
# median    :      65.00
# mean      :      67.82
# Q3        :      95.00
# max       :        184
# mode      :         24
# std dev   :      36.32
# variance  :    1319.03
# IQR       :      58.00

# %% [markdown]
# # Prototype CNN

# %%
sample = "UGH srsly my head is POUNDING! got no sleep AGAIN? fUCK this BS :( cant even think. just wanna cry rn 😭"

# %% [markdown]
# ## Tokenization

# %%
import string

# Create a simple character vocabulary (expand as needed)
all_chars = list(string.ascii_lowercase + string.ascii_uppercase + string.digits +
                 string.punctuation + string.whitespace + "😴😭")
char2idx = {c: i for i, c in enumerate(all_chars)}
vocab_size = len(char2idx)

# Tokenize the sample
tokens = [char2idx.get(c, 0) for c in sample]
print(tokens)
# Out:
# [46, 32, 33, 94, 18, 17, 18, 11, 24, 94, 12, 24, 94, 7, 4, 0, 3, 94, 8, 18, 94, 41, 40, 46, 39, 29, 34, 39, 32, 62, 94, 6, 14, 19, 94, 13, 14, 94, 18, 11, 4, 4, 15, 94, 26, 32, 26, 34, 39, 82, 94, 5, 46, 28, 36, 94, 19, 7, 8, 18, 94, 27, 44, 94, 77, 69, 94, 2, 0, 13, 19, 94, 4, 21, 4, 13, 94, 19, 7, 8, 13, 10, 75, 94, 9, 20, 18, 19, 94, 22, 0, 13, 13, 0, 94, 2, 17, 24, 94, 17, 13, 94, 101]

# %% [markdown]
# ## 16d character vectors

# %%
import torch
import torch.nn as nn

# 16d character embeddings
embedding_dim = 16
embeddings = nn.Embedding(vocab_size, embedding_dim)

char_tensor = torch.tensor(tokens).unsqueeze(0)  # shape: (1, seq_len)
char_embedded = embeddings(char_tensor)          # shape: (1, seq_len, 16)
print(char_embedded.shape)
print(char_embedded[0])  # Print the embeddings for each character
# Out:
# torch.Size([1, 103, 16])
# tensor([[-0.2623,  0.0163, -1.1457,  ...,  0.6902,  2.1133, -0.6992],
#         [-0.8260, -0.3303,  0.3652,  ..., -1.2517,  1.1951, -1.4648],
#         [ 0.6609, -0.7282, -2.1209,  ...,  0.2498, -0.1948,  1.2765],
#         ...,
#         [-0.1701, -0.1885,  2.2750,  ...,  0.2596,  0.0101,  0.9115],
#         [ 0.2483,  1.0729,  0.0862,  ..., -1.0074,  0.0550,  1.2124],
#         [-1.2484,  1.0322,  0.4019,  ...,  2.1959,  0.7616, -0.1421]],
#        grad_fn=<SelectBackward0>)

# %% [markdown]
# ## trigrams

# %%
conv3 = nn.Conv1d(in_channels=embedding_dim, out_channels=21, kernel_size=3, padding=1)
x3 = char_embedded.permute(0, 2, 1)  # (batch, channels, seq_len)
trigrams = conv3(x3)                 # shape: (1, 21, seq_len)
print(trigrams.shape)
print(trigrams[0].permute(1, 0))     # (seq_len, 21)
# Out:
# torch.Size([1, 21, 103])
# tensor([[ 0.8434, -0.3109, -0.1925,  ..., -0.0108, -0.7222, -0.4374],
#         [-0.7701,  0.8539,  0.0445,  ..., -0.6808,  0.3612, -1.0118],
#         [ 0.4776, -1.4395,  0.0045,  ...,  0.5090, -1.1187,  0.0083],
#         ...,
#         [ 0.4338,  0.4519,  0.5709,  ..., -0.6020, -0.4900,  0.7648],
#         [-0.6286,  0.0753, -0.0394,  ...,  0.4521, -0.0223,  0.3231],
#         [-0.0897, -0.2866,  0.7383,  ...,  0.9964, -0.0135,  0.9860]],
#        grad_fn=<PermuteBackward0>)

# %% [markdown]
# ## pentagrams

# %%
conv5 = nn.Conv1d(in_channels=embedding_dim, out_channels=21, kernel_size=5, padding=2)
pentagrams = conv5(x3)               # shape: (1, 21, seq_len)
print(pentagrams.shape)
print(pentagrams[0].permute(1, 0))   # (seq_len, 21)
# Out:
# torch.Size([1, 21, 103])
# tensor([[ 1.4851e-01, -6.4492e-01,  1.0086e-01,  ..., -1.9575e-01,
#          -6.7704e-02,  1.3031e-03],
#         [ 4.5662e-01, -1.8607e-01,  8.0824e-02,  ...,  1.1441e-01,
#          -2.2896e-01,  4.0470e-01],
#         [ 5.4311e-01,  4.8854e-02,  1.2784e-01,  ...,  1.6663e-01,
#           9.3681e-01, -5.3980e-01],
#         ...,
#         [-8.2917e-01, -1.2030e-01, -9.9546e-02,  ..., -9.3146e-04,
#           4.8401e-02, -6.1509e-01],
#         [-1.9747e-01,  3.0172e-01, -1.0470e-01,  ...,  1.2386e-01,
#          -2.2237e-01,  8.5577e-01],
#         [-2.3720e-01,  3.2654e-01,  8.3190e-01,  ..., -1.6210e-02,
#           3.6513e-01,  3.2864e-01]], grad_fn=<PermuteBackward0>)

# %% [markdown]
# ## Heptagrams

# %%
conv7 = nn.Conv1d(in_channels=embedding_dim, out_channels=22, kernel_size=7, padding=3)
heptagrams = conv7(x3)               # shape: (1, 22, seq_len)
print(heptagrams.shape)
print(heptagrams[0].permute(1, 0))   # (seq_len, 22)
# Out:
# torch.Size([1, 22, 103])
# tensor([[-0.9613, -0.0972, -0.0055,  ..., -0.6985,  0.3834, -0.2520],
#         [ 0.1834,  0.4453,  0.6848,  ...,  0.2310, -0.3534, -0.4740],
#         [-0.3222,  0.0558, -0.1360,  ..., -0.4393,  0.5785, -0.0588],
#         ...,
#         [ 0.6411,  1.2671,  0.3996,  ..., -0.3538, -0.2380, -0.7555],
#         [-0.3721,  0.0162,  0.3107,  ..., -0.3084, -0.0530, -0.2694],
#         [-0.1803, -0.2761,  0.2848,  ..., -0.3288,  0.4866, -0.0077]],
#        grad_fn=<PermuteBackward0>)

# %% [markdown]
# ## max pooling

# %%
# For each set of filters, take the max across the time dimension (seq_len)
trigram_pooled = torch.max(trigrams, dim=2).values  # (1, 21)
pentagram_pooled = torch.max(pentagrams, dim=2).values  # (1, 21)
heptagram_pooled = torch.max(heptagrams, dim=2).values  # (1, 22)

print(trigram_pooled)
print(pentagram_pooled)
print(heptagram_pooled)
# Out:
# tensor([[1.3013, 1.5427, 2.2468, 1.0036, 1.4046, 0.9150, 1.4890, 1.1949, 0.7565,
#          1.2674, 1.2192, 1.1675, 1.5283, 1.2138, 1.4194, 1.2331, 2.1170, 0.8631,
#          1.5021, 1.2395, 1.4918]], grad_fn=<MaxBackward0>)
# tensor([[1.1590, 1.3543, 1.5108, 1.6406, 1.1641, 1.5700, 1.5450, 1.3899, 1.3388,
#          1.0595, 1.4415, 0.9235, 1.4136, 1.1643, 1.2055, 1.2433, 1.4730, 1.2623,
#          1.9006, 1.8532, 1.2329]], grad_fn=<MaxBackward0>)
# tensor([[1.1715, 1.4626, 1.6549, 1.7557, 1.4528, 1.7816, 1.5882, 0.9951, 1.3683,
#          1.3420, 1.3783, 1.4369, 1.5178, 1.1643, 0.8128, 1.3049, 1.1771, 0.7145,
#          1.2875, 1.0187, 1.7435, 1.4272]], grad_fn=<MaxBackward0>)

# %% [markdown]
# ## 64d output

# %%
final_cnn_output = torch.cat([trigram_pooled, pentagram_pooled, heptagram_pooled], dim=1)  # (1, 64)
print(final_cnn_output.shape)
print(final_cnn_output)
# Out:
# torch.Size([1, 64])
# tensor([[1.3013, 1.5427, 2.2468, 1.0036, 1.4046, 0.9150, 1.4890, 1.1949, 0.7565,
#          1.2674, 1.2192, 1.1675, 1.5283, 1.2138, 1.4194, 1.2331, 2.1170, 0.8631,
#          1.5021, 1.2395, 1.4918, 1.1590, 1.3543, 1.5108, 1.6406, 1.1641, 1.5700,
#          1.5450, 1.3899, 1.3388, 1.0595, 1.4415, 0.9235, 1.4136, 1.1643, 1.2055,
#          1.2433, 1.4730, 1.2623, 1.9006, 1.8532, 1.2329, 1.1715, 1.4626, 1.6549,
#          1.7557, 1.4528, 1.7816, 1.5882, 0.9951, 1.3683, 1.3420, 1.3783, 1.4369,
#          1.5178, 1.1643, 0.8128, 1.3049, 1.1771, 0.7145, 1.2875, 1.0187, 1.7435,
#          1.4272]], grad_fn=<CatBackward0>)
